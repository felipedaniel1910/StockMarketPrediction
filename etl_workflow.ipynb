# %% [markdown]
# # Process Description: Obtaining Fundamentus Share Data

# %% [markdown]
# ## 1. Web Scraping with Selenium
# - Utilize Selenium, a web automation tool, to navigate to the Fundamentus website.
# - Identify and locate the necessary HTML elements containing the shares data.
# - Use Selenium to interact with the webpage, extract the required information such as stock prices, financial metrics, and other relevant data.

# %% [markdown]
# ## 2. Downloading Files
# - Identify and locate any downloadable files on the Fundamentus website, such as the general balance report of each company.
# - Use Selenium to simulate the process of clicking download buttons or links.
# - Implement logic to wait for file downloads to complete before proceeding.

# %% [markdown]
# ## 3. Extracting from ZIP
# - If the downloaded files are in ZIP format, use Python's zipfile module to programmatically extract the contents.
# - Identify the target files within the ZIP archive that contain the shares data.
# - Extract the relevant files to a specified directory for further processing.

# %% [markdown]
# ## 4. Data Processing
# - Once the shares data is obtained, processed, and extracted, proceed with any necessary data cleaning, transformation, or analysis.
# - Utilize Python libraries such as Pandas for efficient data manipulation.

# %% [markdown]
# ## 5. Data Storage or Analysis
# - Depending on the project requirements, store the processed shares data in a database, XLS file, or other data storage solutions.
# - Conduct further analysis, visualization, or reporting as needed.

# %% [markdown]
# ### So, let's code it!

# %% [markdown]
# ## Import the needed libraries

# %%
# Selenium for web automation
from selenium import webdriver  # pip install selenium or pip install --upgrade selenium
# Webdriver Manager for managing browser drivers
from webdriver_manager.chrome import ChromeDriverManager  # pip install webdriver-manager
# Selenium service for Chrome browser
from selenium.webdriver.chrome.service import Service
# Selenium common locator strategies (By)
from selenium.webdriver.common.by import By
# Time module for handling time-related operations
import time
# NumPy for numerical operations
import numpy as np
# PyAutoGUI for automating mouse and keyboard interactions
import pyautogui
# Selenium Keys for keyboard interactions
from selenium.webdriver.common.keys import Keys
# OS module for interacting with the operating system
import os
# shutil for high-level file operations
import shutil
# sys for accessing Python interpreter variables
import sys
# zipfile for working with ZIP archives
import zipfile
# Custom module for store the paths
import config
# import pandas fro data mining
import pandas as pd
# library to get the Yahoo cotations
import yfinance as yf 
# import math do deal with nan
import math
# deal with excel files
import xlrd
import xlwt
from xlutils.copy import copy

# %% [markdown]
# ## Steps 1, 2 and 3 (Web Scraping with Selenium, Downloading Files and Extracting from ZIP)
#
# ### Automate the process of finding and downloading the files. Moving to desired folder and extracting to XLS files

# %%
# Class definition for FundamentusBot
class FundamentusBot:
    # Constructor to configure the browser
    def __init__(self):
        # Configure Chrome options with download preferences (always ask where to save the file)
        chrome_options = webdriver.ChromeOptions()
        chrome_options.add_experimental_option("prefs", {
            "download.prompt_for_download": True,
            "safebrowsing.enabled": True
        })
        #create the service
        service = Service(ChromeDriverManager().install())
        #create and open the browser
        self.browser = webdriver.Chrome(service=service, options=chrome_options)

    # Method to open the Fundamentus website and navigate to the desired data section
    def open_site(self):
        #navigate to initial page of Fundamentus
        self.browser.get("https://fundamentus.com.br/")
        time.sleep(2) #wait 2 seconds 
        #click to open the Fundamentus Mobile
        self.browser.find_element(By.XPATH, '/html/body/div[1]/div[1]/div[2]/ul[1]/li[5]/a').click()
        time.sleep(3) #wait
        #call the method open_data
        self.open_data()

    # Method to navigate to the data section and process data for a list of companies
    def open_data(self):
        #list of companies of interest
        companies = config.companies
        #iterate the companies list
        for company in companies:
            #get company
            self.company = company
            #call the method that download the information
            self.dwnld_company_info()
        time.sleep(5) #wait
        # call the method that move the .zip files from 'source_path_download' to 'destination_path_zip'
        self.move_files()
        # call the method that extract the XLS files from the .zip and save in 'destination_path_xls'
        self.extract_files()
        # close the browser
        self.browser.quit()

    # Method to download company information from the Fundamentus website
    def dwnld_company_info(self):
        #try to do the sequence of actions
        try:
            # find the search bar and type the company
            self.browser.find_element(By.XPATH, '/html/body/div[1]/div[1]/div[2]/form/input[1]').send_keys(self.company)
            time.sleep(2) #wait
            # press enter to open the company's data
            self.browser.find_element(By.XPATH, '/html/body/div[1]/div[1]/div[2]/form/input[1]').send_keys(Keys.ENTER)
            time.sleep(2) #wait
            # click in 'Informações'
            self.browser.find_element(By.XPATH, '/html/body/div[2]/div[2]/div/div/div[2]/ul/li[3]/span').click()
            time.sleep(2) #wait
            # click in "Balanços em EXCEL"
            self.browser.find_element(By.XPATH, '/html/body/div[2]/div[2]/div/div/div[2]/ul/li[3]/ul/li[10]').click()
            time.sleep(3) #wait
            #get the code of the company 
            paper =self.browser.find_element(By.XPATH, '/html/body/div[2]/div[1]/div/div/div[1]/h1').text
            time.sleep(3) #wait
            # click in "baixar" to download the file
            self.browser.find_element(By.XPATH, '//*[@id="form-planilha"]/a').click()
            time.sleep(3) #wait
            # typing a new name for the downloadable file
            pyautogui.typewrite(f'bal_{paper}.zip')
            time.sleep(3) #wait
            # press ENTER to complete the download
            pyautogui.press('enter')
        # in case of any problem during the actions (try), the exception runs
        except Exception as e:
            # show the errors
            print(f'Error: {e}')
            # print a message
            print(f'There was an errror with the company: {self.company}')

    # Method to move downloaded files to a specified destination
    def move_files(self):
        #get all the files from "download" folder
        files_list = [f for f in os.listdir(config.source_path_download) if os.path.isfile(os.path.join(config.source_path_download, f))]
        # iterate all the files
        for file in files_list:
            # get the first 3 characters of the file name
            file_name = file[0:3]
            # check if the file name starts with 'bal' 
            if file_name == 'bal':
                # Check if the destination file exists
                if os.path.exists(f'{config.destination_path_zip}/{file}'):
                    # If it exists, remove it
                    os.remove(f'{config.destination_path_zip}/{file}')
                # move the file to the desired destination
                shutil.move(f'{config.source_path_download}/{file}', config.destination_path_zip)


    # Method to extract files from ZIP archives
    def extract_files(self):
        # get all the files from the directory
        files_list = [f for f in os.listdir(config.destination_path_zip) if os.path.isfile(os.path.join(config.destination_path_zip, f))]
        # iterate each file
        for file in files_list:
            # get the first 3 characters of the file name
            file_name = file[0:3]
            # check if the file name starts with 'bal' 
            if file_name == 'bal': 
                # Check if the destination file exists
                if os.path.exists(f'{config.destination_path_xls}/{file[0:-4]}.xls'):
                    # If it exists, remove it
                    os.remove(f'{config.destination_path_xls}/{file[0:-4]}.xls') 
                # Using the 'with' statement to open the ZIP archive for reading ('r' mode)
                # The archive file path is constructed using the destination path for ZIP files and the current file in the loop
                with zipfile.ZipFile(f'{config.destination_path_zip}/{file}', 'r') as zip_ref:
                    # Extract the specific file to the specified folder
                    zip_ref.extract('balanco.xls',f'{config.destination_path_xls}/')
                    # Rename the file
                    source_path = f'{config.destination_path_xls}/' #path of the file
                    file_to_rename = 'balanco.xls' #current file name
                    new_filename = f'{file[0:-4]}.xls' #desired file name
                    old_file_path = os.path.join(source_path,file_to_rename) #old file
                    new_file_path = os.path.join(source_path, new_filename) #new file
                    os.rename(old_file_path, new_file_path) #rename
                
# Create an instance of FundamentusBot and execute the process
bot = FundamentusBot()
bot.open_site()
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-2-2f8ebc8c338d> in <module>
#     124 # Create an instance of FundamentusBot and execute the process
#     125 bot = FundamentusBot()
# --> 126 bot.open_site()
#
# <ipython-input-2-2f8ebc8c338d> in open_site(self)
#      20         time.sleep(2) #wait 2 seconds
#      21         #click to open the Fundamentus Mobile
# ---> 22         self.browser.find_element(By.XPATH, '/html/body/div[1]/div[1]/div[2]/ul[1]/li[5]/a').click()
#      23         time.sleep(3) #wait
#      24         #call the method open_data
#
# c:\Users\felip\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     740             value = f'[name="{value}"]'
#     741
# --> 742         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     743
#     744     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# c:\Users\felip\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     346         response = self.command_executor.execute(driver_command, params)
#     347         if response:
# --> 348             self.error_handler.check_response(response)
#     349             response["value"] = self._unwrap_value(response.get("value", None))
#     350             return response
#
# c:\Users\felip\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     227                 alert_text = value["alert"].get("text")
#     228             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229         raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=120.0.6099.72)
# Stacktrace:
# 	GetHandleVerifier [0x01006EE3+174339]
# 	(No symbol) [0x00F30A51]
# 	(No symbol) [0x00C46FF6]
# 	(No symbol) [0x00C2EFE7]
# 	(No symbol) [0x00C9B53B]
# 	(No symbol) [0x00CA9E7B]
# 	(No symbol) [0x00C96DA6]
# 	(No symbol) [0x00C71034]
# 	(No symbol) [0x00C71F8D]
# 	GetHandleVerifier [0x010A4B1C+820540]
# 	sqlite3_dbdata_init [0x011653EE+653550]
# 	sqlite3_dbdata_init [0x01164E09+652041]
# 	sqlite3_dbdata_init [0x011597CC+605388]
# 	sqlite3_dbdata_init [0x01165D9B+656027]
# 	(No symbol) [0x00F3FE6C]
# 	(No symbol) [0x00F383B8]
# 	(No symbol) [0x00F384DD]
# 	(No symbol) [0x00F25818]
# 	BaseThreadInitThunk [0x750DFA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x76FE7A4E+286]
# 	RtlGetAppContainerNamedObjectPath [0x76FE7A1E+238]

# %% [markdown]
# ## Step 4 (Data Processing)

# %% [markdown]
# ### Getting the data from XLS files to process with pandas

# %% [markdown]
# For this first moment, let's just get 1 sample of balance and income (using "break" in the end of the code) to understand the changes that need to be done before inserting the data into a dictionary

# %%
#get all the files available (xls files)
files = os.listdir(config.destination_path_xls)
# iterate for ech file
for file in files:
    #create the file_name to be the key of the dictionary
    if '11' in file: #some codes has 11
        file_name = file[-10:-4] #get the code
    else:
        file_name = file[-9:-4] #get the code
    #check if the file_name is in the list  companies (this is to help in case we want to analyze only some campanies)
    if file_name in config.companies:
        #get the company balance
        balance = pd.read_excel(f'./balances/extracted/{file}', sheet_name=0)
        #get the company income statement
        income = pd.read_excel(f'./balances/extracted/{file}', sheet_name=1)
        break #to get only one result
# Out:
# WARNING *** file size (67047) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (67047) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %% [markdown]
# ### Let's see the head of both tables to understand what need to be done first

# %%
balance.head()
# Out:
#   XLSWrite 1.34 Copyright(c) 1999,2000 Axolot Data  \
# 0                                              NaN
# 1                                      Ativo Total
# 2                                 Ativo Circulante
# 3                    Caixa e Equivalentes de Caixa
# 4                           Aplicações Financeiras
#
#   Balanço Patrimonial - AMBEV S/A   Unnamed: 2    Unnamed: 3    Unnamed: 4  \
# 0                      31/12/2012   31/03/2013    30/06/2013    30/09/2013
# 1                     1346301.056  1340374.016  58739269.632  59618975.744
# 2                           71641        77552   12057052.16  12478373.888
# 3                           48155        74204   4482174.976   4835169.792
# 4                               0            0    486132.992    612489.024
#
#      Unnamed: 5    Unnamed: 6    Unnamed: 7    Unnamed: 8    Unnamed: 9  ...  \
# 0    31/12/2013    31/03/2014    30/06/2014    30/09/2014    31/12/2014  ...
# 1  68674015.232   63297044.48   62989045.76  65125920.768  72143200.256  ...
# 2  20470011.904  16352306.176  15773268.992  15446576.128  20728420.352  ...
# 3  11285832.704   7296176.128   6273862.144   5748115.968   9722066.944  ...
# 4        288604    410172.992    379937.984    526788.992    712958.016  ...
#
#      Unnamed: 35    Unnamed: 36    Unnamed: 37    Unnamed: 38    Unnamed: 39  \
# 0     30/06/2021     30/09/2021     31/12/2021     31/03/2022     30/06/2022
# 1  124440133.632  135133249.536  138602479.616  127399919.616  136633409.536
# 2   32705665.024   38197080.064   38627139.584   34479796.224   38238560.256
# 3   13269346.304   17956171.776   16627697.664   12887921.664   14129258.496
# 4     1245607.04    2044573.952    1914606.976    1345730.048    1535714.048
#
#      Unnamed: 40    Unnamed: 41   Unnamed: 42    Unnamed: 43   Unnamed: 44
# 0     30/09/2022     31/12/2022    31/03/2023     30/06/2023    30/09/2023
# 1  142063960.064  137958080.512  135466721.28  133294415.872  137914204.16
# 2   41556963.328   37816713.216      35378688   34324092.928  37552668.672
# 3   17712654.336   14926435.328  12214085.632   12117013.504  17413906.432
# 4        1347216     454496.992        365284         313504        227164
#
# [5 rows x 45 columns]

# %%
income.head(5)
# Out:
#   XLSWrite 1.34 Copyright(c) 1999,2000 Axolot Data  \
# 0
# 1            Receita Bruta de Vendas e/ou Serviços
# 2                        Deduções da Receita Bruta
# 3          Receita Líquida de Vendas e/ou Serviços
# 4             Custo de Bens e/ou Serviços Vendidos
#
#    Demonstrativo de Resultado - AMBEV S/A - Trimestres Isolados  Unnamed: 2  \
# 0                                                NaN             31/03/2013
# 1                                                NaN                    NaN
# 2                                                NaN                    NaN
# 3                                                NaN                  10617
# 4                                                NaN                      0
#
#     Unnamed: 3   Unnamed: 4   Unnamed: 5   Unnamed: 6   Unnamed: 7  \
# 0   30/06/2013   30/09/2013   31/12/2013   31/03/2014   30/06/2014
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3  7503133.184  8462602.752  18815037.44  9045071.872  8177433.088
# 4 -2626988.032 -2834846.976 -5935966.208 -3008314.112 -3040666.112
#
#     Unnamed: 8    Unnamed: 9  ...   Unnamed: 35   Unnamed: 36   Unnamed: 37  \
# 0   30/09/2014    31/12/2014  ...    30/06/2021    30/09/2021    31/12/2021
# 1          NaN           NaN  ...           NaN           NaN           NaN
# 2          NaN           NaN  ...           NaN           NaN           NaN
# 3  8624396.288  12232882.176  ...  15711140.864  18492608.512  22010836.992
# 4 -2955760.128  -3809847.552  ...  -7965268.992  -9253070.848 -10496073.728
#
#     Unnamed: 38   Unnamed: 39   Unnamed: 40   Unnamed: 41   Unnamed: 42  \
# 0    31/03/2022    30/06/2022    30/09/2022    31/12/2022    31/03/2023
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3  18439151.616  17988995.072   20587642.88  22693033.984  20531744.768
# 4  -9414486.016   -9374254.08 -10648073.216 -10985254.912 -10131684.352
#
#    Unnamed: 43   Unnamed: 44
# 0   30/06/2023    30/09/2023
# 1          NaN           NaN
# 2          NaN           NaN
# 3  18898114.56  20317763.584
# 4 -9635608.576 -10223017.984
#
# [5 rows x 45 columns]

# %% [markdown]
# ### It is possible to see that in both dataframes we need to:
#
# - Insert the company code in the first column (header)
# - Transform the first row in a the header
# - Transform first column into index

# %%
# Insert the company code in the first column (header)
balance.iloc[0,0] = file_name
income.iloc[0,0] = file_name

# %%
# Transform the first row in a the header
balance.columns = balance.iloc[0] #insert first row as header
balance = balance[1:] #get first row until the end (drop the line 0 that was duplicated)
income.columns = income.iloc[0] #insert first row as header
income = income[1:] #get first row until the end (drop the line 0 that was duplicated)

# %%
# Transform first column into index
balance = balance.set_index(file_name)
income = income.set_index(file_name)

# %% [markdown]
# ### Let's take a look in the columns

# %%
#show columns
print(balance.columns)
print(income.columns)
# Out:
# Index(['31/12/2012', '31/03/2013', '30/06/2013', '30/09/2013', '31/12/2013',
#        '31/03/2014', '30/06/2014', '30/09/2014', '31/12/2014', '31/03/2015',
#        '30/06/2015', '30/09/2015', '31/12/2015', '31/03/2016', '30/06/2016',
#        '30/09/2016', '31/12/2016', '31/03/2017', '30/06/2017', '30/09/2017',
#        '31/12/2017', '31/03/2018', '30/06/2018', '30/09/2018', '31/12/2018',
#        '31/03/2019', '30/06/2019', '30/09/2019', '31/12/2019', '31/03/2020',
#        '30/06/2020', '30/09/2020', '31/12/2020', '31/03/2021', '30/06/2021',
#        '30/09/2021', '31/12/2021', '31/03/2022', '30/06/2022', '30/09/2022',
#        '31/12/2022', '31/03/2023', '30/06/2023', '30/09/2023'],
#       dtype='object', name=0)
# Index([         nan, '31/03/2013', '30/06/2013', '30/09/2013', '31/12/2013',
#        '31/03/2014', '30/06/2014', '30/09/2014', '31/12/2014', '31/03/2015',
#        '30/06/2015', '30/09/2015', '31/12/2015', '31/03/2016', '30/06/2016',
#        '30/09/2016', '31/12/2016', '31/03/2017', '30/06/2017', '30/09/2017',
#        '31/12/2017', '31/03/2018', '30/06/2018', '30/09/2018', '31/12/2018',
#        '31/03/2019', '30/06/2019', '30/09/2019', '31/12/2019', '31/03/2020',
#        '30/06/2020', '30/09/2020', '31/12/2020', '31/03/2021', '30/06/2021',
#        '30/09/2021', '31/12/2021', '31/03/2022', '30/06/2022', '30/09/2022',
#        '31/12/2022', '31/03/2023', '30/06/2023', '30/09/2023'],
#       dtype='object', name=0)

# %% [markdown]
# It is possible to see that the balance contains data from 31/12/2012 and income dataframe starts in 31/03/2013
#
# So let's drop the first column of balance table, this way both will have data from the same period. For the complete data we will do it later, to have the big picture of the time ranges.

# %%
#drop first columns of balance
balance = balance.drop(columns=balance.columns[0], axis=1)
#drop first column of income (used a different methos due the nan name of the column)
del income[income.columns[0]]

# %%
#show columns
print(balance.columns)
print(income.columns)
# Out:
# Index(['31/03/2013', '30/06/2013', '30/09/2013', '31/12/2013', '31/03/2014',
#        '30/06/2014', '30/09/2014', '31/12/2014', '31/03/2015', '30/06/2015',
#        '30/09/2015', '31/12/2015', '31/03/2016', '30/06/2016', '30/09/2016',
#        '31/12/2016', '31/03/2017', '30/06/2017', '30/09/2017', '31/12/2017',
#        '31/03/2018', '30/06/2018', '30/09/2018', '31/12/2018', '31/03/2019',
#        '30/06/2019', '30/09/2019', '31/12/2019', '31/03/2020', '30/06/2020',
#        '30/09/2020', '31/12/2020', '31/03/2021', '30/06/2021', '30/09/2021',
#        '31/12/2021', '31/03/2022', '30/06/2022', '30/09/2022', '31/12/2022',
#        '31/03/2023', '30/06/2023', '30/09/2023'],
#       dtype='object', name=0)
# Index(['31/03/2013', '30/06/2013', '30/09/2013', '31/12/2013', '31/03/2014',
#        '30/06/2014', '30/09/2014', '31/12/2014', '31/03/2015', '30/06/2015',
#        '30/09/2015', '31/12/2015', '31/03/2016', '30/06/2016', '30/09/2016',
#        '31/12/2016', '31/03/2017', '30/06/2017', '30/09/2017', '31/12/2017',
#        '31/03/2018', '30/06/2018', '30/09/2018', '31/12/2018', '31/03/2019',
#        '30/06/2019', '30/09/2019', '31/12/2019', '31/03/2020', '30/06/2020',
#        '30/09/2020', '31/12/2020', '31/03/2021', '30/06/2021', '30/09/2021',
#        '31/12/2021', '31/03/2022', '30/06/2022', '30/09/2022', '31/12/2022',
#        '31/03/2023', '30/06/2023', '30/09/2023'],
#       dtype='object', name=0)

# %% [markdown]
# ### Now we are ready to collect the data of all the companies and insert into the dictionary

# %%
#create a dictionary to store the data
fundamentus = {}
#get all the files available (xls files)
files = os.listdir(config.destination_path_xls)
# iterate for ech file
for file in files:
    #create the file_name to be the key of the dictionary
    if '11' in file: #some codes has 11
        file_name = file[-10:-4] #get the code
    else:
        file_name = file[-9:-4] #get the code
    #check if the file_name is in the list  companies (this is to help in case we want to analyze only some campanies)
    if file_name in config.companies:
        #get the company balance
        balance = pd.read_excel(f'./balances/extracted/{file}', sheet_name=0)
        #get the company income statement
        income = pd.read_excel(f'./balances/extracted/{file}', sheet_name=1)
        # Insert the company code in the first column (header)
        balance.iloc[0,0] = file_name
        income.iloc[0,0] = file_name
        # Transform the first row in a the header
        balance.columns = balance.iloc[0] #insert first row as header
        balance = balance[1:] #get first row until the end (drop the line 0 that was duplicated)
        income.columns = income.iloc[0] #insert first row as header
        income = income[1:] #get first row until the end (drop the line 0 that was duplicated)
        # Transform first column into index
        balance = balance.set_index(file_name)
        income = income.set_index(file_name)
        # Insert data into the dictionary
        #fundamentus[file_name] = balance._append(income)  
        fundamentus[file_name] = pd.concat([balance,income])
        # drop the columns name 'nan'
        for i in range(0,len(fundamentus[file_name].columns)): #repeat from 0 to len(columns)
            # need the try due and error on the check for non numeric columns headers
            try:
                if math.isnan(fundamentus[file_name].columns[i]): #check if it is a nan
                    # drop columns in case of yes
                    fundamentus[file_name] = fundamentus[file_name].drop(columns=fundamentus[file_name].columns[i])
            # do nothing in case of error on the try
            except: 
                None # do nothing
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (45071) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (45071) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (82419) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (82419) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90643) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90643) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90721) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90721) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90867) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90867) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90777) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90777) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (88979) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (88979) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90717) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90717) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90717) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90717) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90741) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90741) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90717) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90717) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (45087) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (45087) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (89670) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (89670) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90713) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90713) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (67067) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (67067) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90747) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90747) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90292) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90292) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90733) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90733) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90727) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90727) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90721) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90721) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90759) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90759) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90717) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90717) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90723) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90723) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90753) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90753) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90717) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90717) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (85356) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (85356) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90603) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90603) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (28981) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (28981) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90617) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90617) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90773) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90773) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (39709) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (39709) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64200) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64200) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90719) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90719) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90723) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90723) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90719) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90719) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (95455) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (95455) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90659) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90659) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90725) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90725) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90719) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90719) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64222) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64222) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (73615) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (73615) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90701) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90701) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (77805) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (77805) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90721) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90721) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90713) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90713) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90725) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90725) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (30654) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (30654) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90733) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90733) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90725) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90725) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (83473) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (83473) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (77801) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (77801) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90371) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90371) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90725) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90725) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90745) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90745) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (94891) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (94891) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (89945) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (89945) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64202) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64202) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90731) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90731) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90717) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90717) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (34153) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (34153) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90717) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90717) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90757) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90757) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90723) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90723) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90715) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90715) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90731) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90731) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90719) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90719) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90727) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (90727) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %% [markdown]
# ### Getting the historical prices of shares

# %% [markdown]
# Selecting the end date (date of the last balance of companies) and creating the start date (getting last 5 years of data)

# %%
# end date 
from datetime import datetime, timedelta #library needed to deal with times
end_date = fundamentus[config.companies[1]].columns[-1] # get the last column (last date)
end_date_dt = datetime.strptime(end_date, "%d/%m/%Y") #trasnform string to datetime
start_date_dt = (end_date_dt - timedelta(days= 5 * 365)) #Create the start_date based on time variation 
end_date_str = end_date_dt.strftime("%Y-%m-%d") #transform end_date to string to match the needed format
start_date_str = start_date_dt.strftime("%Y-%m-%d") # transform start_date to string to match the needed format
print(f'Start date: {end_date_str}') #print
print(f'End date: {start_date_str}') #print
# Out:
# Start date: 2023-09-30
# End date: 2018-10-01

# %% [markdown]
# Get the cotations for the desired companies

# %%
cotation = {} #create a dictionary
# get the cotation of the desired companies
for company in  config.companies: # loop to get the cotations
    cotation_df = yf.download(f"{company}.SA", start=start_date_str, end=end_date_str, progress=False) # get the cotation
    cotation_df['Company'] = company # insert the company name
    cotation[company] = cotation_df #insert dataframe to the dictionary

cotation_bkp = cotation # create a dataframe for backup (only during development)
# Out:
# 1 Failed download:
# ['BRML3.SA']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['HGTX3.SA']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CPLE6.SA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-10-01 -> 2023-09-30)')
#
# 1 Failed download:
# ['CSAN3.SA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-10-01 -> 2023-09-30)')
#
# 1 Failed download:
# ['CPFE3.SA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-10-01 -> 2023-09-30)')
#
# 1 Failed download:
# ['CVCB3.SA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-10-01 -> 2023-09-30)')
#
# 1 Failed download:
# ['CYRE3.SA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-10-01 -> 2023-09-30)')
#
# 1 Failed download:
# ['ECOR3.SA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-10-01 -> 2023-09-30)')
#
# 1 Failed download:
# ['ELET6.SA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-10-01 -> 2023-09-30)')
#
# 1 Failed download:
# ['EMBR3.SA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-10-01 -> 2023-09-30)')
# Failed to get ticker 'ENBR3.SA' reason: HTTPSConnectionPool(host='query2.finance.yahoo.com', port=443): Max retries exceeded with url: /v8/finance/chart/ENBR3.SA?range=1d&interval=1d&crumb=stz0jINQc0E (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000028424B25460>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# 1 Failed download:
# ['ENBR3.SA']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['ENGI11.SA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-10-01 -> 2023-09-30)')
#
# 1 Failed download:
# ['ENEV3.SA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-10-01 -> 2023-09-30)')
#
# 1 Failed download:
# ['EGIE3.SA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-10-01 -> 2023-09-30)')
#
# 1 Failed download:
# ['EQTL3.SA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-10-01 -> 2023-09-30)')
#
# 1 Failed download:
# ['EZTC3.SA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-10-01 -> 2023-09-30)')
#
# 1 Failed download:
# ['FLRY3.SA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-10-01 -> 2023-09-30)')
#
# 1 Failed download:
# ['GGBR4.SA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-10-01 -> 2023-09-30)')
#
# 1 Failed download:
# ['GOAU4.SA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-10-01 -> 2023-09-30)')
#
# 1 Failed download:
# ['GOLL4.SA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-10-01 -> 2023-09-30)')
#
# 1 Failed download:
# ['NTCO3.SA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-10-01 -> 2023-09-30)')
#
# 1 Failed download:
# ['HAPV3.SA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-10-01 -> 2023-09-30)')
#
# 1 Failed download:
# ['HYPE3.SA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-10-01 -> 2023-09-30)')
# Failed to get ticker 'IGTA3.SA' reason: HTTPSConnectionPool(host='query2.finance.yahoo.com', port=443): Max retries exceeded with url: /v8/finance/chart/IGTA3.SA?range=1d&interval=1d&crumb=stz0jINQc0E (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000028423685790>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# 1 Failed download:
# ['IGTA3.SA']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Failed to get ticker 'GNDI3.SA' reason: HTTPSConnectionPool(host='query2.finance.yahoo.com', port=443): Max retries exceeded with url: /v8/finance/chart/GNDI3.SA?range=1d&interval=1d&crumb=stz0jINQc0E (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000284236851F0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# 1 Failed download:
# ['GNDI3.SA']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['ITSA4.SA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-10-01 -> 2023-09-30)')
#
# 1 Failed download:
# ['ITUB4.SA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-10-01 -> 2023-09-30)')
#
# 1 Failed download:
# ['JBSS3.SA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-10-01 -> 2023-09-30)')
#
# 1 Failed download:
# ['JHSF3.SA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-10-01 -> 2023-09-30)')
#
# 1 Failed download:
# ['KLBN11.SA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-10-01 -> 2023-09-30)')
#
# 1 Failed download:
# ['RENT3.SA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-10-01 -> 2023-09-30)')
# Failed to get ticker 'LCAM3.SA' reason: HTTPSConnectionPool(host='query2.finance.yahoo.com', port=443): Max retries exceeded with url: /v8/finance/chart/LCAM3.SA?range=1d&interval=1d&crumb=stz0jINQc0E (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000028425BC8CD0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# 1 Failed download:
# ['LCAM3.SA']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Failed to get ticker 'LAME4.SA' reason: HTTPSConnectionPool(host='query2.finance.yahoo.com', port=443): Max retries exceeded with url: /v8/finance/chart/LAME4.SA?range=1d&interval=1d&crumb=stz0jINQc0E (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000028425BC8C10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# 1 Failed download:
# ['LAME4.SA']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['LREN3.SA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-10-01 -> 2023-09-30)')
#
# 1 Failed download:
# ['MGLU3.SA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-10-01 -> 2023-09-30)')
#
# 1 Failed download:
# ['MRFG3.SA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-10-01 -> 2023-09-30)')
#
# 1 Failed download:
# ['BRDT3.SA']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['SULA11.SA']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['VVAR3.SA']: Exception('%ticker%: No timezone found, symbol may be delisted')

# %% [markdown]
# Compare and correct the period of the fundamentus data and cotations (the period need to match - so we want analyze last 5 years)

# %%
list(fundamentus.keys())[0]
# Out:
# 'ABEV3'

# %%
# look to the time period of fundamentus data (based on the first company in the dictionary (AMBEV - ABEV3))
fundamentus[list(fundamentus.keys())[0]].columns
# Out:
# Index(['31/12/2012', '31/03/2013', '30/06/2013', '30/09/2013', '31/12/2013',
#        '31/03/2014', '30/06/2014', '30/09/2014', '31/12/2014', '31/03/2015',
#        '30/06/2015', '30/09/2015', '31/12/2015', '31/03/2016', '30/06/2016',
#        '30/09/2016', '31/12/2016', '31/03/2017', '30/06/2017', '30/09/2017',
#        '31/12/2017', '31/03/2018', '30/06/2018', '30/09/2018', '31/12/2018',
#        '31/03/2019', '30/06/2019', '30/09/2019', '31/12/2019', '31/03/2020',
#        '30/06/2020', '30/09/2020', '31/12/2020', '31/03/2021', '30/06/2021',
#        '30/09/2021', '31/12/2021', '31/03/2022', '30/06/2022', '30/09/2022',
#        '31/12/2022', '31/03/2023', '30/06/2023', '30/09/2023'],
#       dtype='object', name=0)

# %%
# Converting the index as date
#fundamentus['ABEV3'].index = pd.to_datetime(fundamentus['ABEV3'].index)
type(cotation[list(fundamentus.keys())[0]].index.values[1])
date = cotation[list(fundamentus.keys())[0]].index.values[1]
print(date)
# Converter para objeto datetime
data_datetime = np.datetime_as_string(date, unit='D')  # 'D' representa dias
print(data_datetime)
# Formatar a data no formato desejado
data_formatada = datetime.strptime(data_datetime, "%Y-%m-%d").strftime("%d/%m/%Y")
print(data_formatada)
# Out:
# 2018-10-02T00:00:00.000000000
# 2018-10-02
# 02/10/2018

# %% [markdown]
# Filling the needed date range

# %%
# organize the columns of fundamentus to same format as cotation date
cols = fundamentus[list(fundamentus.keys())[0]].columns #get the columns of first dataframe (key = ABEV3)
new_cols = [] #create a list to store the new columns names
for col in cols: #loop
    # convert string to datetime object
    col = datetime.strptime(col, "%d/%m/%Y")
    # convert datetime object to numpy.datetime64 (as in the cotations dataframe)
    col = np.datetime64(col)
    #save in the new_cols list
    new_cols.append(col)

# transform start date to numpy.datetime64 format to compare all the dates
start_date_np = datetime.strptime(start_date_dt.strftime("%d/%m/%Y"), "%d/%m/%Y") #correct the format
start_date_np = np.datetime64(start_date_np) #transform to numpy datetime 64 bits
new_cols_remove = [] #create as new list to insert the cols that need to be deleted from fundamentus dataframe
for col in new_cols: #loop
    if col < start_date_np: # check if the col in fundamentus table is lower (older) than start date
        new_cols_remove.append(col) # in case of yes, select this col to be deleted from fundamentus

new_cols = [item for item in new_cols if item not in new_cols_remove] #update new columns for fundamentus

#show neww columns
display(new_cols)
# convert string to datetime object
new_cols_dt = np.datetime_as_string(date, unit='D')  # 'D' represent days
print(new_cols_dt) #print
# Select the desired date format
new_cols_dt = datetime.strptime(new_cols_dt, "%Y-%m-%d").strftime("%d/%m/%Y")
print(new_cols_dt) #print

#index
x = 0
#new_cols = new_cols
# loop the check all the index from cotation
for col in new_cols:
    # loop for each key in the cotation dictionary
    for company in list(fundamentus.keys()):
        # if the date from fundamentus is in cotation, do nothing
        if col in cotation[company].index:
            print('OK')
        # if the date is not in the cotation, need to create
        else: 
            # print message
            print(f'Need to add {col} in the cotation table')
            # increment index
            x += 1
            # loop to subtract days until find a valid one to get the cotation
            for sub_days in range (1,10):
                # subtract 1 day
                days = np.timedelta64(sub_days, 'D') #create the variabele with 1 day
                date_sub_x_days = col - days # subtract 1 day
                # check if the new data exists in cotation to get the price
                if date_sub_x_days in cotation[company].index: 
                    #once the date is found, get the price and create the needed date
                    new_line_data = pd.Series(name=col, data = cotation[company].loc[date_sub_x_days])
                    print(new_line_data)
                    break
            # add the new line with the needed date to the cotation dataframe
            cotation[company] = cotation[company]._append(new_line_data)
            print('Added') #print
# Out:
# [numpy.datetime64('2018-12-31T00:00:00.000000'),
#  numpy.datetime64('2019-03-31T00:00:00.000000'),
#  numpy.datetime64('2019-06-30T00:00:00.000000'),
#  numpy.datetime64('2019-09-30T00:00:00.000000'),
#  numpy.datetime64('2019-12-31T00:00:00.000000'),
#  numpy.datetime64('2020-03-31T00:00:00.000000'),
#  numpy.datetime64('2020-06-30T00:00:00.000000'),
#  numpy.datetime64('2020-09-30T00:00:00.000000'),
#  numpy.datetime64('2020-12-31T00:00:00.000000'),
#  numpy.datetime64('2021-03-31T00:00:00.000000'),
#  numpy.datetime64('2021-06-30T00:00:00.000000'),
#  numpy.datetime64('2021-09-30T00:00:00.000000'),
#  numpy.datetime64('2021-12-31T00:00:00.000000'),
#  numpy.datetime64('2022-03-31T00:00:00.000000'),
#  numpy.datetime64('2022-06-30T00:00:00.000000'),
#  numpy.datetime64('2022-09-30T00:00:00.000000'),
#  numpy.datetime64('2022-12-31T00:00:00.000000'),
#  numpy.datetime64('2023-03-31T00:00:00.000000'),
#  numpy.datetime64('2023-06-30T00:00:00.000000'),
#  numpy.datetime64('2023-09-30T00:00:00.000000')]
# 2018-10-02
# 02/10/2018
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Open             15.23
# High             15.67
# Low               15.2
# Close            15.38
# Adj Close    12.625372
# Volume        15498800
# Company          ABEV3
# Name: 2018-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Open              35.0
# High              36.0
# Low          34.619999
# Close             36.0
# Adj Close         36.0
# Volume         2607400
# Company          AZUL4
# Name: 2018-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Open         8.766666
# High         9.033333
# Low          8.763333
# Close        8.936666
# Adj Close    7.502092
# Volume       36834600
# Company         B3SA3
# Name: 2018-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Open         45.189999
# High         46.490002
# Low          44.849998
# Close        46.490002
# Adj Close     33.95599
# Volume        12985900
# Company          BBAS3
# Name: 2018-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Open         23.754068
# High         24.267467
# Low          23.603806
# Close        24.198597
# Adj Close    18.887291
# Volume        19362695
# Company          BBDC4
# Name: 2018-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Open             27.25
# High         27.889999
# Low              27.25
# Close            27.59
# Adj Close    18.726107
# Volume         3366600
# Company          BBSE3
# Name: 2018-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Open         4.818144
# High         4.906641
# Low          4.808311
# Close        4.906641
# Adj Close    3.884951
# Volume        1592401
# Company         BEEF3
# Name: 2018-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Open            5.805
# High             5.92
# Low             5.805
# Close          5.8875
# Adj Close    5.184355
# Volume        5064800
# Company        BPAC11
# Name: 2018-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Open         27.215582
# High         28.056662
# Low          27.215582
# Close        28.056662
# Adj Close    14.795377
# Volume         4106523
# Company          BRAP4
# Name: 2018-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Open           21.85
# High           22.18
# Low            21.74
# Close          21.93
# Adj Close      21.93
# Volume       3809200
# Company        BRFS3
# Name: 2018-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Open             47.02
# High         47.380001
# Low          46.610001
# Close        47.380001
# Adj Close    36.498314
# Volume         1615600
# Company          BRKM5
# Name: 2018-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Open            11.43
# High            11.63
# Low              11.2
# Close            11.2
# Adj Close    9.671972
# Volume        5722600
# Company         CCRO3
# Name: 2018-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Open             8.82
# High              9.1
# Low              8.82
# Close            8.89
# Adj Close    6.791683
# Volume        8580400
# Company         CIEL3
# Name: 2018-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Open         8.985622
# High         9.184419
# Low          8.945863
# Close        9.184419
# Adj Close    5.703174
# Volume       15726548
# Company         CMIG4
# Name: 2018-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Open             8.84
# High              9.0
# Low               8.8
# Close            8.87
# Adj Close    8.766041
# Volume        7636300
# Company         COGN3
# Name: 2018-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Open         18.040001
# High             18.32
# Low              17.99
# Close            18.09
# Adj Close    16.395313
# Volume         2186900
# Company          CRFB3
# Name: 2018-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Open              8.7
# High             8.84
# Low              8.63
# Close            8.84
# Adj Close    5.884201
# Volume        5024700
# Company         CSNA3
# Name: 2018-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Open              12.2
# High             12.41
# Low              12.01
# Close            12.36
# Adj Close    10.514098
# Volume         2762400
# Company          MRVE3
# Name: 2018-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Open         23.879999
# High         24.370001
# Low          23.379999
# Close        24.309999
# Adj Close    21.209373
# Volume         3329700
# Company          MULT3
# Name: 2018-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Open         85.010002
# High         85.010002
# Low          85.010002
# Close        85.010002
# Adj Close     77.65081
# Volume               0
# Company          PCAR3
# Name: 2018-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Open         22.110001
# High             22.83
# Low              22.08
# Close            22.68
# Adj Close     8.078734
# Volume        61634700
# Company          PETR4
# Name: 2018-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Open           2.0098
# High           2.0286
# Low            1.9766
# Close           1.984
# Adj Close    1.980818
# Volume        1890000
# Company         PRIO3
# Name: 2018-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Open             12.65
# High             13.02
# Low              12.58
# Close            12.89
# Adj Close    10.678152
# Volume         2623600
# Company          QUAL3
# Name: 2018-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Open          11.14423
# High          11.14423
# Low          10.884615
# Close        10.990384
# Adj Close    10.501542
# Volume         5963360
# Company          RADL3
# Name: 2018-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Open             16.48
# High              17.0
# Low              16.33
# Close             17.0
# Adj Close    16.923368
# Volume         8687200
# Company          RAIL3
# Name: 2018-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Open         42.540001
# High         43.099998
# Low              42.07
# Close        42.919998
# Adj Close    31.276936
# Volume         1352300
# Company         SANB11
# Name: 2018-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Open             31.17
# High         31.540001
# Low              30.67
# Close             31.5
# Adj Close    28.053253
# Volume         1812000
# Company          SBSP3
# Name: 2018-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Open         37.209999
# High         38.080002
# Low          36.619999
# Close        38.080002
# Adj Close    34.702675
# Volume         3976300
# Company          SUZB3
# Name: 2018-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Open         23.690001
# High             23.75
# Low          23.389999
# Close             23.6
# Adj Close    14.759043
# Volume         1052300
# Company         TAEE11
# Name: 2018-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Open            11.78
# High            11.93
# Low             11.68
# Close           11.85
# Adj Close    9.503482
# Volume        3586900
# Company         TIMS3
# Name: 2018-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Open         9.056126
# High         9.122666
# Low          8.903084
# Close        9.032837
# Adj Close    8.562625
# Volume        1033359
# Company         TOTS3
# Name: 2018-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Open            26.035
# High             26.74
# Low             26.035
# Close             26.6
# Adj Close    23.962803
# Volume         3498000
# Company          UGPA3
# Name: 2018-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Open             9.17
# High              9.3
# Low              9.09
# Close            9.22
# Adj Close    7.505784
# Volume       14571200
# Company         USIM5
# Name: 2018-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Open         50.310001
# High         51.200001
# Low              50.25
# Close             51.0
# Adj Close    34.788666
# Volume        11914300
# Company          VALE3
# Name: 2018-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Open         40.790001
# High         41.970001
# Low               40.5
# Close        41.290001
# Adj Close    28.826677
# Volume           29700
# Company          VIVT3
# Name: 2018-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Open             8.59
# High             8.93
# Low             8.555
# Close            8.77
# Adj Close    8.186917
# Volume        7181000
# Company         WEGE3
# Name: 2018-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2018-12-31T00:00:00.000000 in the cotation table
# Open         23.440001
# High         24.219999
# Low              23.26
# Close            23.76
# Adj Close    22.091749
# Volume         3284400
# Company          YDUQ3
# Name: 2018-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Open         16.870001
# High         16.969999
# Low          16.700001
# Close            16.83
# Adj Close     13.81567
# Volume        15839700
# Company          ABEV3
# Name: 2019-03-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Open           37.75
# High           38.27
# Low             37.0
# Close          38.27
# Adj Close      38.27
# Volume       2449100
# Company        AZUL4
# Name: 2019-03-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Open         10.806666
# High         10.806666
# Low          10.536666
# Close        10.706666
# Adj Close     9.040344
# Volume        27680400
# Company          B3SA3
# Name: 2019-03-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Open         48.700001
# High         49.369999
# Low              48.25
# Close        48.720001
# Adj Close    36.089859
# Volume        10937100
# Company          BBAS3
# Name: 2019-03-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Open         26.734283
# High         26.884546
# Low          26.471325
# Close        26.884546
# Adj Close    21.011856
# Volume        26932625
# Company          BBDC4
# Name: 2019-03-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Open             26.23
# High             26.66
# Low          26.139999
# Close            26.52
# Adj Close    18.439888
# Volume         5783400
# Company          BBSE3
# Name: 2019-03-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Open         6.932228
# High         7.020724
# Low           6.87323
# Close        6.912562
# Adj Close    5.473188
# Volume        1802409
# Company         BEEF3
# Name: 2019-03-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Open             8.75
# High             9.01
# Low            8.6575
# Close          8.9675
# Adj Close    8.101309
# Volume        3119200
# Company        BPAC11
# Name: 2019-03-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Open         27.534307
# High          28.33112
# Low          27.534307
# Close        28.242584
# Adj Close    15.202387
# Volume         2923371
# Company          BRAP4
# Name: 2019-03-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Open             22.65
# High         23.049999
# Low              22.33
# Close            22.65
# Adj Close        22.65
# Volume        10852000
# Company          BRFS3
# Name: 2019-03-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Open         51.540001
# High         51.970001
# Low          50.310001
# Close        50.900002
# Adj Close    39.209881
# Volume         1322400
# Company          BRKM5
# Name: 2019-03-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Open             11.81
# High             11.95
# Low              11.49
# Close            11.74
# Adj Close    10.138301
# Volume        10868200
# Company          CCRO3
# Name: 2019-03-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Open             9.63
# High             9.72
# Low              9.38
# Close            9.49
# Adj Close    7.463455
# Volume        9210200
# Company         CIEL3
# Name: 2019-03-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Open          9.14466
# High         9.270564
# Low          9.071767
# Close        9.210925
# Adj Close    5.719633
# Volume       13583507
# Company         CMIG4
# Name: 2019-03-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Open             10.65
# High             10.72
# Low              10.27
# Close             10.6
# Adj Close    10.475765
# Volume        20191000
# Company          COGN3
# Name: 2019-03-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Open             20.15
# High             20.34
# Low          19.959999
# Close            20.09
# Adj Close    18.207947
# Volume         1932600
# Company          CRFB3
# Name: 2019-03-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Open         16.120001
# High             16.77
# Low              16.07
# Close            16.25
# Adj Close    10.816545
# Volume        22145800
# Company          CSNA3
# Name: 2019-03-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Open             13.92
# High             14.11
# Low              13.75
# Close            13.99
# Adj Close    11.900666
# Volume         4535600
# Company          MRVE3
# Name: 2019-03-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Open         23.629999
# High         23.809999
# Low              23.08
# Close        23.389999
# Adj Close    20.506054
# Volume         3661100
# Company          MULT3
# Name: 2019-03-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Open              93.5
# High              93.5
# Low               93.5
# Close             93.5
# Adj Close    86.030815
# Volume               0
# Company          PCAR3
# Name: 2019-03-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Open         28.450001
# High         28.530001
# Low              27.74
# Close        28.059999
# Adj Close     9.995119
# Volume        51587400
# Company          PETR4
# Name: 2019-03-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Open            3.858
# High             3.96
# Low              3.78
# Close            3.78
# Adj Close    3.773938
# Volume        9040500
# Company         PRIO3
# Name: 2019-03-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Open             15.47
# High             15.81
# Low              15.22
# Close            15.68
# Adj Close    12.989405
# Volume         2874100
# Company          QUAL3
# Name: 2019-03-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Open         12.507692
# High         12.809615
# Low          12.413461
# Close        12.557692
# Adj Close    12.030582
# Volume         3958760
# Company          RADL3
# Name: 2019-03-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Open             19.18
# High             19.32
# Low              18.68
# Close            19.15
# Adj Close    19.063677
# Volume        16998000
# Company          RAIL3
# Name: 2019-03-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Open         43.689999
# High         44.040001
# Low          43.200001
# Close        43.709999
# Adj Close     32.72966
# Volume          723800
# Company         SANB11
# Name: 2019-03-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Open              42.0
# High         42.400002
# Low              41.16
# Close             42.0
# Adj Close    37.404331
# Volume         9373100
# Company          SBSP3
# Name: 2019-03-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Open         46.009998
# High         46.560001
# Low          45.849998
# Close        46.549999
# Adj Close    42.421463
# Volume         4264500
# Company          SUZB3
# Name: 2019-03-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Open             24.85
# High              25.5
# Low          24.719999
# Close            24.84
# Adj Close    15.534521
# Volume         1937300
# Company         TAEE11
# Name: 2019-03-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Open            11.84
# High            12.02
# Low             11.79
# Close           11.79
# Adj Close    9.579144
# Volume        4120600
# Company         TIMS3
# Name: 2019-03-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Open         13.161659
# High         13.304721
# Low          12.898825
# Close        13.108427
# Adj Close    12.462693
# Volume         4442124
# Company          TOTS3
# Name: 2019-03-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Open         23.985001
# High         24.190001
# Low          23.280001
# Close             23.5
# Adj Close    21.298759
# Volume         5447600
# Company          UGPA3
# Name: 2019-03-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Open             9.84
# High            10.15
# Low              9.83
# Close           10.04
# Adj Close    8.237721
# Volume       17280800
# Company         USIM5
# Name: 2019-03-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Open         49.950001
# High         51.599998
# Low          49.950001
# Close            50.93
# Adj Close    34.740913
# Volume        25118100
# Company          VALE3
# Name: 2019-03-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Open         43.580002
# High              44.0
# Low               43.5
# Close             44.0
# Adj Close    30.998064
# Volume           11900
# Company          VIVT3
# Name: 2019-03-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Open            9.11
# High            9.16
# Low            8.955
# Close            9.0
# Adj Close     8.4599
# Volume       4381800
# Company        WEGE3
# Name: 2019-03-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-03-31T00:00:00.000000 in the cotation table
# Open             27.07
# High             27.07
# Low          26.190001
# Close             26.6
# Adj Close    24.732347
# Volume         3425800
# Company          YDUQ3
# Name: 2019-03-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Open             18.16
# High         18.200001
# Low          17.780001
# Close        17.889999
# Adj Close    14.685819
# Volume        17249500
# Company          ABEV3
# Name: 2019-06-30T00:00:00.000000, dtype: object
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Open         42.799999
# High         43.290001
# Low          42.439999
# Close        43.290001
# Adj Close    43.290001
# Volume         2473000
# Company          AZUL4
# Name: 2019-06-30T00:00:00.000000, dtype: object
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Open         12.733333
# High             12.75
# Low          12.436666
# Close        12.486666
# Adj Close     10.59691
# Volume        24124800
# Company          B3SA3
# Name: 2019-06-30T00:00:00.000000, dtype: object
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Open         54.279999
# High         54.279999
# Low          53.349998
# Close        53.939999
# Adj Close     40.42691
# Volume        14197400
# Company          BBAS3
# Name: 2019-06-30T00:00:00.000000, dtype: object
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Open          28.64012
# High          28.76033
# Low          28.324568
# Close         28.35462
# Adj Close    22.195711
# Volume        22523048
# Company          BBDC4
# Name: 2019-06-30T00:00:00.000000, dtype: object
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Open         32.599998
# High             32.73
# Low          32.380001
# Close        32.380001
# Adj Close    22.514463
# Volume         2527200
# Company          BBSE3
# Name: 2019-06-30T00:00:00.000000, dtype: object
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Open         7.797527
# High         7.886024
# Low          7.787694
# Close        7.817193
# Adj Close    6.189451
# Volume        1522025
# Company         BEEF3
# Name: 2019-06-30T00:00:00.000000, dtype: object
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Open            12.425
# High             12.72
# Low             12.275
# Close            12.72
# Adj Close    11.491346
# Volume        46755600
# Company         BPAC11
# Name: 2019-06-30T00:00:00.000000, dtype: object
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Open         29.260735
# High         29.305002
# Low          28.942009
# Close        29.083666
# Adj Close    15.952632
# Volume         2326995
# Company          BRAP4
# Name: 2019-06-30T00:00:00.000000, dtype: object
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Open             29.15
# High         29.870001
# Low               29.0
# Close            29.52
# Adj Close        29.52
# Volume         7414400
# Company          BRFS3
# Name: 2019-06-30T00:00:00.000000, dtype: object
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Open         35.049999
# High              35.5
# Low               35.0
# Close        35.029999
# Adj Close    28.983452
# Volume         1490800
# Company          BRKM5
# Name: 2019-06-30T00:00:00.000000, dtype: object
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Open             13.88
# High             13.96
# Low              13.66
# Close            13.66
# Adj Close    12.090724
# Volume         8599900
# Company          CCRO3
# Name: 2019-06-30T00:00:00.000000, dtype: object
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Open              6.9
# High             6.94
# Low              6.68
# Close            6.72
# Adj Close    5.448277
# Volume       14235600
# Company         CIEL3
# Name: 2019-06-30T00:00:00.000000, dtype: object
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Open         9.807316
# High         9.933221
# Low          9.754304
# Close        9.840449
# Adj Close    6.307032
# Volume       12861716
# Company         CMIG4
# Name: 2019-06-30T00:00:00.000000, dtype: object
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Open              11.0
# High              11.0
# Low              10.84
# Close            10.97
# Adj Close    10.931742
# Volume         7782400
# Company          COGN3
# Name: 2019-06-30T00:00:00.000000, dtype: object
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Open             21.85
# High             22.08
# Low          21.690001
# Close             22.0
# Adj Close    19.983356
# Volume         3001600
# Company          CRFB3
# Name: 2019-06-30T00:00:00.000000, dtype: object
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Open             16.66
# High         16.799999
# Low          16.469999
# Close        16.709999
# Adj Close    12.205303
# Volume        10241200
# Company          CSNA3
# Name: 2019-06-30T00:00:00.000000, dtype: object
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Open         19.440001
# High              19.9
# Low               19.4
# Close            19.57
# Adj Close      17.0079
# Volume         3620600
# Company          MRVE3
# Name: 2019-06-30T00:00:00.000000, dtype: object
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Open         27.469999
# High         27.780001
# Low          27.129999
# Close            27.76
# Adj Close    24.503466
# Volume         4281600
# Company          MULT3
# Name: 2019-06-30T00:00:00.000000, dtype: object
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Open              93.5
# High              93.5
# Low               93.5
# Close             93.5
# Adj Close    86.150185
# Volume               0
# Company          PCAR3
# Name: 2019-06-30T00:00:00.000000, dtype: object
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Open         27.450001
# High         27.610001
# Low          27.110001
# Close            27.41
# Adj Close      9.80746
# Volume        40262000
# Company          PETR4
# Name: 2019-06-30T00:00:00.000000, dtype: object
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Open            3.164
# High            3.196
# Low             3.074
# Close           3.154
# Adj Close    3.148942
# Volume        6187000
# Company         PRIO3
# Name: 2019-06-30T00:00:00.000000, dtype: object
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Open         22.799999
# High             23.25
# Low              22.65
# Close        22.969999
# Adj Close    19.762987
# Volume         2475700
# Company          QUAL3
# Name: 2019-06-30T00:00:00.000000, dtype: object
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Open         14.576923
# High         14.780769
# Low          14.513461
# Close        14.634615
# Adj Close    14.051396
# Volume         5190120
# Company          RADL3
# Name: 2019-06-30T00:00:00.000000, dtype: object
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Open             20.58
# High             20.98
# Low              20.51
# Close            20.73
# Adj Close    20.636555
# Volume        11511500
# Company          RAIL3
# Name: 2019-06-30T00:00:00.000000, dtype: object
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Open         46.080002
# High         46.240002
# Low          45.459999
# Close        45.459999
# Adj Close    34.240612
# Volume         1010600
# Company         SANB11
# Name: 2019-06-30T00:00:00.000000, dtype: object
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Open         46.290001
# High         47.360001
# Low          46.259998
# Close            47.27
# Adj Close    43.148979
# Volume         2060700
# Company          SBSP3
# Name: 2019-06-30T00:00:00.000000, dtype: object
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Open         33.700001
# High         33.799999
# Low          32.169998
# Close        32.849998
# Adj Close    30.264542
# Volume        10510100
# Company          SUZB3
# Name: 2019-06-30T00:00:00.000000, dtype: object
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Open         27.139999
# High             27.49
# Low              26.99
# Close            27.16
# Adj Close    17.294044
# Volume         1304200
# Company         TAEE11
# Name: 2019-06-30T00:00:00.000000, dtype: object
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Open            11.66
# High             11.7
# Low             11.51
# Close           11.63
# Adj Close    9.449147
# Volume        5176400
# Company         TIMS3
# Name: 2019-06-30T00:00:00.000000, dtype: object
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Open             14.61
# High         14.723333
# Low          14.433333
# Close        14.656666
# Adj Close    13.934665
# Volume         5124600
# Company          TOTS3
# Name: 2019-06-30T00:00:00.000000, dtype: object
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Open             20.66
# High             20.73
# Low               20.0
# Close             20.1
# Adj Close    18.217234
# Volume         7387400
# Company          UGPA3
# Name: 2019-06-30T00:00:00.000000, dtype: object
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Open             8.75
# High              9.0
# Low              8.74
# Close            8.94
# Adj Close    7.392344
# Volume       19631300
# Company         USIM5
# Name: 2019-06-30T00:00:00.000000, dtype: object
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Open             52.07
# High         52.200001
# Low          51.689999
# Close            51.82
# Adj Close    35.348007
# Volume        11106100
# Company          VALE3
# Name: 2019-06-30T00:00:00.000000, dtype: object
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Open            43.57
# High            43.57
# Low             42.25
# Close           42.25
# Adj Close    30.98114
# Volume          63000
# Company         VIVT3
# Name: 2019-06-30T00:00:00.000000, dtype: object
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Open              10.8
# High            10.915
# Low              10.68
# Close            10.68
# Adj Close    10.039084
# Volume         4775200
# Company          WEGE3
# Name: 2019-06-30T00:00:00.000000, dtype: object
# Added
# Need to add 2019-06-30T00:00:00.000000 in the cotation table
# Open         29.049999
# High         29.389999
# Low          28.629999
# Close             29.0
# Adj Close     27.46517
# Volume         3348200
# Company          YDUQ3
# Name: 2019-06-30T00:00:00.000000, dtype: object
# Added
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# Need to add 2019-09-30T00:00:00.000000 in the cotation table
# Added
# OK
# OK
# OK
# OK
# Need to add 2019-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-09-30T00:00:00.000000 in the cotation table
# Added
# OK
# Need to add 2019-09-30T00:00:00.000000 in the cotation table
# Added
# OK
# Need to add 2019-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-09-30T00:00:00.000000 in the cotation table
# Added
# OK
# OK
# Need to add 2019-09-30T00:00:00.000000 in the cotation table
# Added
# OK
# OK
# OK
# OK
# OK
# OK
# Need to add 2019-09-30T00:00:00.000000 in the cotation table
# Added
# OK
# OK
# Need to add 2019-09-30T00:00:00.000000 in the cotation table
# Added
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Open         19.200001
# High             19.35
# Low              18.67
# Close            18.67
# Adj Close    15.728645
# Volume        17430500
# Company          ABEV3
# Name: 2019-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Open         57.599998
# High         58.799999
# Low              57.43
# Close        58.279999
# Adj Close    58.279999
# Volume         1615700
# Company          AZUL4
# Name: 2019-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Open             14.74
# High         14.776666
# Low          14.283333
# Close        14.323333
# Adj Close    12.275269
# Volume        54656400
# Company          B3SA3
# Name: 2019-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Open         53.099998
# High             53.34
# Low              52.82
# Close            52.82
# Adj Close    40.627163
# Volume         7839900
# Company          BBAS3
# Name: 2019-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Open         27.317806
# High         27.415478
# Low          27.017281
# Close        27.175056
# Adj Close    22.451193
# Volume         9923270
# Company          BBDC4
# Name: 2019-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Open             37.91
# High             38.16
# Low          37.650002
# Close        37.700001
# Adj Close    26.895487
# Volume         1299200
# Company          BBSE3
# Name: 2019-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Open         12.527175
# High         12.664837
# Low          12.320683
# Close        12.625505
# Adj Close     9.996549
# Volume         4496718
# Company          BEEF3
# Name: 2019-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Open         18.997499
# High             19.18
# Low          18.754999
# Close             18.9
# Adj Close    17.265087
# Volume         3013600
# Company         BPAC11
# Name: 2019-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Open         34.059319
# High         34.386894
# Low          33.607792
# Close        33.891102
# Adj Close    18.976778
# Volume         1776477
# Company          BRAP4
# Name: 2019-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Open         35.220001
# High              35.5
# Low              35.07
# Close        35.200001
# Adj Close    35.200001
# Volume         2067400
# Company          BRFS3
# Name: 2019-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Open             30.59
# High         30.719999
# Low              29.85
# Close            29.85
# Adj Close    25.393274
# Volume         2277400
# Company          BRKM5
# Name: 2019-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Open             19.15
# High         19.440001
# Low              18.92
# Close            18.98
# Adj Close    17.247435
# Volume         3616800
# Company          CCRO3
# Name: 2019-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Open             8.57
# High             8.67
# Low              8.37
# Close            8.37
# Adj Close    6.826148
# Volume        9824600
# Company         CIEL3
# Name: 2019-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Open         9.065141
# High         9.197672
# Low          9.045261
# Close        9.138033
# Adj Close    5.976501
# Volume        6444364
# Company         CMIG4
# Name: 2019-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Open           11.68
# High           11.73
# Low            11.38
# Close          11.43
# Adj Close      11.43
# Volume       9320800
# Company        COGN3
# Name: 2019-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Open             23.34
# High         23.639999
# Low          23.059999
# Close            23.35
# Adj Close    21.429686
# Volume         2800700
# Company          CRFB3
# Name: 2019-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Open            13.97
# High            14.38
# Low             13.93
# Close           14.11
# Adj Close    10.52367
# Volume        8340300
# Company         CSNA3
# Name: 2019-12-31T00:00:00.000000, dtype: object
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2019-12-31T00:00:00.000000 in the cotation table
# Added
# ...
# Added
# Need to add 2023-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-03-31T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-03-31T00:00:00.000000 in the cotation table
# Added
# OK
# OK
# Need to add 2023-03-31T00:00:00.000000 in the cotation table
# Added
# OK
# OK
# OK
# OK
# OK
# OK
# Need to add 2023-03-31T00:00:00.000000 in the cotation table
# Added
# OK
# OK
# Need to add 2023-03-31T00:00:00.000000 in the cotation table
# Added
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# Need to add 2023-06-30T00:00:00.000000 in the cotation table
# Added
# OK
# OK
# OK
# OK
# Need to add 2023-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-06-30T00:00:00.000000 in the cotation table
# Added
# OK
# Need to add 2023-06-30T00:00:00.000000 in the cotation table
# Added
# OK
# Need to add 2023-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-06-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-06-30T00:00:00.000000 in the cotation table
# Added
# OK
# OK
# Need to add 2023-06-30T00:00:00.000000 in the cotation table
# Added
# OK
# OK
# OK
# OK
# OK
# OK
# Need to add 2023-06-30T00:00:00.000000 in the cotation table
# Added
# OK
# OK
# Need to add 2023-06-30T00:00:00.000000 in the cotation table
# Added
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Open             13.08
# High             13.17
# Low              13.05
# Close            13.11
# Adj Close    12.458781
# Volume        22876500
# Company          ABEV3
# Name: 2023-09-30T00:00:00.000000, dtype: object
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Open           14.28
# High           14.68
# Low            14.23
# Close          14.48
# Adj Close      14.48
# Volume       8478100
# Company        AZUL4
# Name: 2023-09-30T00:00:00.000000, dtype: object
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Open             12.42
# High             12.49
# Low              12.13
# Close            12.29
# Adj Close    12.205094
# Volume        23002700
# Company          B3SA3
# Name: 2023-09-30T00:00:00.000000, dtype: object
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Open             47.84
# High         47.889999
# Low          47.099998
# Close            47.18
# Adj Close    46.790115
# Volume         5453200
# Company          BBAS3
# Name: 2023-09-30T00:00:00.000000, dtype: object
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Open             14.33
# High             14.38
# Low              14.14
# Close             14.3
# Adj Close    13.823446
# Volume        20641500
# Company          BBDC4
# Name: 2023-09-30T00:00:00.000000, dtype: object
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Open         31.790001
# High         31.799999
# Low          31.200001
# Close        31.209999
# Adj Close    31.209999
# Volume         4972000
# Company          BBSE3
# Name: 2023-09-30T00:00:00.000000, dtype: object
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Open            8.21
# High            8.29
# Low             8.06
# Close           8.09
# Adj Close       8.09
# Volume       9251300
# Company        BEEF3
# Name: 2023-09-30T00:00:00.000000, dtype: object
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Open         31.059999
# High         31.280001
# Low              30.74
# Close            31.07
# Adj Close    30.739693
# Volume         6052800
# Company         BPAC11
# Name: 2023-09-30T00:00:00.000000, dtype: object
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Open              22.6
# High         22.879999
# Low              22.48
# Close        22.719999
# Adj Close    21.214144
# Volume         3690800
# Company          BRAP4
# Name: 2023-09-30T00:00:00.000000, dtype: object
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Open            10.21
# High            10.35
# Low              10.0
# Close           10.19
# Adj Close       10.19
# Volume       23108000
# Company         BRFS3
# Name: 2023-09-30T00:00:00.000000, dtype: object
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Open           20.52
# High           20.93
# Low            20.52
# Close          20.52
# Adj Close      20.52
# Volume       2691400
# Company        BRKM5
# Name: 2023-09-30T00:00:00.000000, dtype: object
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Open             12.96
# High              13.0
# Low              12.84
# Close            12.89
# Adj Close    12.723129
# Volume        12049500
# Company          CCRO3
# Name: 2023-09-30T00:00:00.000000, dtype: object
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Open             3.49
# High             3.56
# Low              3.49
# Close            3.51
# Adj Close    3.394993
# Volume       36313300
# Company         CIEL3
# Name: 2023-09-30T00:00:00.000000, dtype: object
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Open             12.48
# High              12.5
# Low              12.22
# Close            12.41
# Adj Close    11.760855
# Volume         7282800
# Company          CMIG4
# Name: 2023-09-30T00:00:00.000000, dtype: object
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Open              2.7
# High             2.74
# Low              2.66
# Close            2.66
# Adj Close        2.66
# Volume       24209300
# Company         COGN3
# Name: 2023-09-30T00:00:00.000000, dtype: object
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Open            8.97
# High            9.16
# Low             8.78
# Close            8.9
# Adj Close        8.9
# Volume       8434500
# Company        CRFB3
# Name: 2023-09-30T00:00:00.000000, dtype: object
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Open             12.15
# High             12.24
# Low               12.1
# Close            12.14
# Adj Close    11.585767
# Volume         3944300
# Company          CSNA3
# Name: 2023-09-30T00:00:00.000000, dtype: object
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Open            10.55
# High            10.75
# Low             10.41
# Close           10.67
# Adj Close       10.67
# Volume       16827900
# Company         MRVE3
# Name: 2023-09-30T00:00:00.000000, dtype: object
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Open         24.639999
# High         24.860001
# Low               24.4
# Close            24.57
# Adj Close    24.186527
# Volume         4626300
# Company          MULT3
# Name: 2023-09-30T00:00:00.000000, dtype: object
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Open             3.41
# High             3.54
# Low              3.37
# Close             3.5
# Adj Close         3.5
# Volume       11466200
# Company         PCAR3
# Name: 2023-09-30T00:00:00.000000, dtype: object
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Open              34.5
# High         34.689999
# Low              34.25
# Close        34.639999
# Adj Close    33.358292
# Volume        40227600
# Company          PETR4
# Name: 2023-09-30T00:00:00.000000, dtype: object
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Open             47.75
# High         47.849998
# Low          45.259998
# Close        47.040001
# Adj Close    46.964569
# Volume        14768700
# Company          PRIO3
# Name: 2023-09-30T00:00:00.000000, dtype: object
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Open            3.03
# High            3.19
# Low             3.03
# Close           3.08
# Adj Close       3.08
# Volume       6534500
# Company        QUAL3
# Name: 2023-09-30T00:00:00.000000, dtype: object
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Open             27.58
# High         27.950001
# Low          27.469999
# Close        27.620001
# Adj Close    27.471642
# Volume         9860300
# Company          RADL3
# Name: 2023-09-30T00:00:00.000000, dtype: object
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Open         22.940001
# High         23.040001
# Low          22.639999
# Close            22.82
# Adj Close        22.82
# Volume        11891300
# Company          RAIL3
# Name: 2023-09-30T00:00:00.000000, dtype: object
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Open         26.200001
# High         26.360001
# Low              26.02
# Close        26.049999
# Adj Close    25.658068
# Volume          864300
# Company         SANB11
# Name: 2023-09-30T00:00:00.000000, dtype: object
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Open         60.799999
# High         61.560001
# Low               60.5
# Close        61.029999
# Adj Close    61.029999
# Volume         4084700
# Company          SBSP3
# Name: 2023-09-30T00:00:00.000000, dtype: object
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Open              55.0
# High         55.099998
# Low              53.98
# Close        54.279999
# Adj Close    53.039616
# Volume         5343100
# Company          SUZB3
# Name: 2023-09-30T00:00:00.000000, dtype: object
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Open         34.580002
# High         34.860001
# Low          34.459999
# Close        34.560001
# Adj Close    33.407856
# Volume         1365600
# Company         TAEE11
# Name: 2023-09-30T00:00:00.000000, dtype: object
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Open             15.02
# High             15.03
# Low              14.86
# Close            14.89
# Adj Close    14.666159
# Volume         6696300
# Company          TIMS3
# Name: 2023-09-30T00:00:00.000000, dtype: object
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Open             26.91
# High         27.389999
# Low          26.799999
# Close             27.0
# Adj Close    26.834015
# Volume         4040400
# Company          TOTS3
# Name: 2023-09-30T00:00:00.000000, dtype: object
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Open             18.83
# High         18.860001
# Low          18.559999
# Close            18.75
# Adj Close        18.75
# Volume         4941000
# Company          UGPA3
# Name: 2023-09-30T00:00:00.000000, dtype: object
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Open            6.62
# High            6.67
# Low             6.62
# Close           6.64
# Adj Close       6.64
# Volume       8163500
# Company        USIM5
# Name: 2023-09-30T00:00:00.000000, dtype: object
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Open         67.309998
# High         67.650002
# Low          67.040001
# Close        67.580002
# Adj Close     66.91568
# Volume        19018000
# Company          VALE3
# Name: 2023-09-30T00:00:00.000000, dtype: object
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Open         43.349998
# High             43.57
# Low          42.860001
# Close            43.18
# Adj Close    42.681637
# Volume         3273200
# Company          VIVT3
# Name: 2023-09-30T00:00:00.000000, dtype: object
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Open         36.619999
# High         36.709999
# Low          36.150002
# Close            36.27
# Adj Close    36.197578
# Volume         5247900
# Company          WEGE3
# Name: 2023-09-30T00:00:00.000000, dtype: object
# Added
# Need to add 2023-09-30T00:00:00.000000 in the cotation table
# Open         19.809999
# High             20.26
# Low          19.549999
# Close        19.870001
# Adj Close    19.870001
# Volume         3847600
# Company          YDUQ3
# Name: 2023-09-30T00:00:00.000000, dtype: object
# Added

# %%
cotation.keys()
# Out:
# dict_keys(['ABEV3', 'AZUL4', 'B3SA3', 'BBSE3', 'BRML3', 'BBDC4', 'BRAP4', 'BBAS3', 'BRKM5', 'BRFS3', 'BPAC11', 'CRFB3', 'CCRO3', 'CMIG4', 'HGTX3', 'CIEL3', 'COGN3', 'CPLE6', 'CSAN3', 'CPFE3', 'CVCB3', 'CYRE3', 'ECOR3', 'ELET6', 'EMBR3', 'ENBR3', 'ENGI11', 'ENEV3', 'EGIE3', 'EQTL3', 'EZTC3', 'FLRY3', 'GGBR4', 'GOAU4', 'GOLL4', 'NTCO3', 'HAPV3', 'HYPE3', 'IGTA3', 'GNDI3', 'ITSA4', 'ITUB4', 'JBSS3', 'JHSF3', 'KLBN11', 'RENT3', 'LCAM3', 'LAME4', 'LREN3', 'MGLU3', 'MRFG3', 'BEEF3', 'MRVE3', 'MULT3', 'PCAR3', 'PETR4', 'BRDT3', 'PRIO3', 'QUAL3', 'RADL3', 'RAIL3', 'SBSP3', 'SANB11', 'CSNA3', 'SULA11', 'SUZB3', 'TAEE11', 'VIVT3', 'TIMS3', 'TOTS3', 'UGPA3', 'USIM5', 'VALE3', 'VVAR3', 'WEGE3', 'YDUQ3'])

# %% [markdown]
# Compare and check if we have cotation for all the companies in fundamentus e drop those that are not in both datasets

# %%
#check difference 
print(f'Quantity companyes in fundamentus: {len(list(fundamentus.keys()))}')
print(f'Quantity companyes in cotation: {len(list(cotation.keys()))}')
# Out:
# Quantity companyes in fundamentus: 74
# Quantity companyes in cotation: 76

# %%
# Companies in fundamentus but not in cotation
companies_to_drop= [i for i in list(fundamentus.keys()) if (i not in list(cotation.keys()))]
#drop companies in fundamentus
for company in companies_to_drop:
    fundamentus.pop(company)

# Companies in cotation but not in fundamentus
companies_to_drop= [i for i in list(cotation.keys()) if (i not in list(fundamentus.keys()))]
#drop companies in fundamentus
for company in companies_to_drop:
    cotation.pop(company)

# %%
#check difference 
print(f'Quantity companyes in fundamentus: {len(list(fundamentus.keys()))}')
print(f'Quantity companyes in cotation: {len(list(cotation.keys()))}')
# Out:
# Quantity companyes in fundamentus: 74
# Quantity companyes in cotation: 74

# %% [markdown]
#  Drop companies with null values in cotation

# %%
#list of companies
list_companies = list(cotation.keys())
# loop to check all companies
for company in list_companies:
    # check if there are nulls
    if cotation[company].isnull().values.any():
        #drop company
        cotation.pop(company)
        fundamentus.pop(company)

# %%
#check difference 
print(f'Quantity companyes in fundamentus: {len(list(fundamentus.keys()))}')
print(f'Quantity companyes in cotation: {len(list(cotation.keys()))}')
# Out:
# Quantity companyes in fundamentus: 74
# Quantity companyes in cotation: 74

# %%
fundamentus['B3SA3']

# %% [markdown]
# Merge fundamentus and cotation into the same dictionary

# %%
# create dictionary to store all the data
historic = {}
# Loop to sweep all the companies
for company in list_companies:
    # creating a table
    table_fundamentus = fundamentus[company].T #insert dates in index
    # changing index to datetime python
    table_fundamentus.index = pd.to_datetime(table_fundamentus.index, format="%d/%m/%Y")
    # get cotation - only adj close is desired
    table_cotation = cotation[company]
    table_cotation = table_cotation[['Adj Close']]
    # final table
    table = table_fundamentus.merge(table_cotation, right_index=True, left_index=True) #only lines in both tables at same time
    # insert the company in the index header
    table.index_name = company
    # save ina new dataframe
    historic[company] = table

# %%
fundamentus['B3SA3']
# Out:
# 0                                           31/12/2008    31/03/2009  \
# B3SA3
# 20753426.432                              20430088.192  21204279.296
# 2408035.072                                1965460.992   2814573.056
# 2055229.056                                1784295.936   2592073.984
# 0                                                    0             0
# 329968.992                                  163303.008    196336.992
# ...                                                ...           ...
# IR Diferido                                      32961         -7237
# Participações/Contribuições Estatutárias             0             0
# Reversão dos Juros sobre Capital Próprio             0             0
# Part. de Acionistas Não Controladores             -606          -295
# Lucro/Prejuízo do Período                   115390.016        226980
#
# 0                                         30/06/2009    30/09/2009  \
# B3SA3
# 20753426.432                              20936243.2  21292857.344
# 2408035.072                                  2569664    2936913.92
# 2055229.056                                  2335424   2701556.992
# 0                                                  0             0
# 329968.992                                    206844        209856
# ...                                              ...           ...
# IR Diferido                                  -152196        -60196
# Participações/Contribuições Estatutárias           0             0
# Reversão dos Juros sobre Capital Próprio           0             0
# Part. de Acionistas Não Controladores            251         -1029
# Lucro/Prejuízo do Período                     188130        245766
#
# 0                                           31/12/2009    31/03/2010  \
# B3SA3
# 20753426.432                              21201184.768  21615536.128
# 2408035.072                                2778968.064   4192899.072
# 2055229.056                                2650563.072   4038099.968
# 0                                                    0             0
# 329968.992                                       97036        129052
# ...                                                ...           ...
# IR Diferido                                -116961.016       -108310
# Participações/Contribuições Estatutárias             0             0
# Reversão dos Juros sobre Capital Próprio             0             0
# Part. de Acionistas Não Controladores               54             0
# Lucro/Prejuízo do Período                   220173.984    284215.008
#
# 0                                           30/06/2010    30/09/2010  \
# B3SA3
# 20753426.432                              21304356.864  22771748.864
# 2408035.072                                3786267.904   3131595.008
# 2055229.056                                    3619712   2960681.984
# 0                                                    0             0
# 329968.992                                      140072    142880.992
# ...                                                ...           ...
# IR Diferido                                    -101836       -125761
# Participações/Contribuições Estatutárias             0             0
# Reversão dos Juros sobre Capital Próprio             0             0
# Part. de Acionistas Não Controladores                0             0
# Lucro/Prejuízo do Período                       305220        293208
#
# 0                                           31/12/2010    31/03/2011  ...  \
# B3SA3                                                                 ...
# 20753426.432                              22633975.808  24032278.528  ...
# 2408035.072                                 2547589.12   3779795.968  ...
# 2055229.056                                     104017   1542301.056  ...
# 0                                          2264408.064   2031428.992  ...
# 329968.992                                       51399         67326  ...
# ...                                                ...           ...  ...
# IR Diferido                                -106713.992       -111167  ...
# Participações/Contribuições Estatutárias           NaN           NaN  ...
# Reversão dos Juros sobre Capital Próprio           NaN           NaN  ...
# Part. de Acionistas Não Controladores               75          -537  ...
# Lucro/Prejuízo do Período                   261918.016        270756  ...
#
# 0                                           30/06/2021    30/09/2021  \
# B3SA3
# 20753426.432                              49530806.272  54807453.696
# 2408035.072                               19873683.456   25600839.68
# 2055229.056                                    2065184   3777044.992
# 0                                         16274057.216  20196892.672
# 329968.992                                  391166.016    369465.984
# ...                                                ...           ...
# IR Diferido                                -323121.984       -146460
# Participações/Contribuições Estatutárias           NaN           NaN
# Reversão dos Juros sobre Capital Próprio           NaN           NaN
# Part. de Acionistas Não Controladores               25            32
# Lucro/Prejuízo do Período                  1193336.064   1176129.024
#
# 0                                           31/12/2021    31/03/2022  \
# B3SA3
# 20753426.432                              52531769.344  50737246.208
# 2408035.072                               21095032.832   19784017.92
# 2055229.056                                2560516.096   2711499.008
# 0                                         16576854.016  15857626.112
# 329968.992                                  436257.984    417460.992
# ...                                                ...           ...
# IR Diferido                                 -92729.056       -379316
# Participações/Contribuições Estatutárias           NaN           NaN
# Reversão dos Juros sobre Capital Próprio           NaN           NaN
# Part. de Acionistas Não Controladores              -60           -98
# Lucro/Prejuízo do Período                  1091593.856   1100945.024
#
# 0                                           30/06/2022    30/09/2022  \
# B3SA3
# 20753426.432                              47394320.384  48771391.488
# 2408035.072                               16721852.416  18498359.296
# 2055229.056                                 2371543.04    4267671.04
# 0                                         12803062.784  12481081.344
# 329968.992                                  431342.016    452375.008
# ...                                                ...           ...
# IR Diferido                                     -30583         77418
# Participações/Contribuições Estatutárias           NaN           NaN
# Reversão dos Juros sobre Capital Próprio           NaN           NaN
# Part. de Acionistas Não Controladores              -95          -196
# Lucro/Prejuízo do Período                  1092182.016   1029100.032
#
# 0                                           31/12/2022    31/03/2023  \
# B3SA3
# 20753426.432                              47594770.432  45806399.488
# 2408035.072                               17129612.288  15579206.656
# 2055229.056                                2613794.048   1929953.024
# 0                                         12290716.672  12239222.784
# 329968.992                                      503840        464980
# ...                                                ...           ...
# IR Diferido                                  36949.992        -41253
# Participações/Contribuições Estatutárias           NaN           NaN
# Reversão dos Juros sobre Capital Próprio           NaN           NaN
# Part. de Acionistas Não Controladores             -152          -107
# Lucro/Prejuízo do Período                  1003829.888    1089351.04
#
# 0                                           30/06/2023    30/09/2023
# B3SA3
# 20753426.432                              47176957.952  47872684.032
# 2408035.072                               16141927.424   17212887.04
# 2055229.056                                2170661.888    3174522.88
# 0                                         12092050.432   11756456.96
# 329968.992                                  504895.008    475030.016
# ...                                                ...           ...
# IR Diferido                                     -27164        -60232
# Participações/Contribuições Estatutárias           NaN           NaN
# Reversão dos Juros sobre Capital Próprio           NaN           NaN
# Part. de Acionistas Não Controladores             -148           -66
# Lucro/Prejuízo do Período                  1052793.984   1074241.024
#
# [79 rows x 60 columns]

# %% [markdown]
# Remove tables that have different (non-standard) columns

# %%
#list of companies
list_companies = list(cotation.keys())
# create columns list
cols = list(historic[list(fundamentus.keys())[0]].columns) # get cols of first company as standard
print(len(list_companies))
# look all the companies to check the columns
for company in list_companies:
    # compare the sets
    if set(cols) != set(historic[company].columns):
        print(company)
        print("Different")
        print(cols)
        print(historic[company].columns)
        # drop if the sets are different
        historic.pop(company)

#update the companies list
list_companies = list(historic.keys())
# Out:
# 74
# B3SA3
# Different
# ['Ativo Total', 'Ativo Circulante', 'Caixa e Equivalentes de Caixa', 'Aplicações Financeiras', 'Contas a Receber', 'Estoques', 'Ativos Biológicos', 'Tributos a Recuperar', 'Despesas Antecipadas', 'Outros Ativos Circulantes', 'Ativo Realizável a Longo Prazo', 'Aplicações Financeiras Avaliadas a Valor Justo', 'Aplicações Financeiras Avaliadas ao Custo Amortizado', 'Contas a Receber', 'Estoques', 'Ativos Biológicos', 'Tributos Diferidos', 'Despesas Antecipadas', 'Créditos com Partes Relacionadas', 'Outros Ativos Não Circulantes', 'Investimentos', 'Imobilizado', 'Intangível', 'Diferido', 'Passivo Total', 'Passivo Circulante', 'Obrigações Sociais e Trabalhistas', 'Fornecedores', 'Obrigações Fiscais', 'Empréstimos e Financiamentos', 'Passivos com Partes Relacionadas', 'Dividendos e JCP a Pagar', 'Outros', 'Provisões', 'Passivos sobre Ativos Não-Correntes a Venda e Descontinuados', 'Passivo Não Circulante', 'Empréstimos e Financiamentos', 'Passivos com Partes Relacionadas', 'Outros', 'Tributos Diferidos', 'Adiantamento para Futuro Aumento Capital', 'Provisões', 'Passivos sobre Ativos Não-Correntes a Venda e Descontinuados', 'Lucros e Receitas a Apropriar', 'Participação dos Acionistas Não Controladores', 'Patrimônio Líquido', 'Capital Social Realizado', 'Reservas de Capital', 'Reservas de Reavaliação', 'Reservas de Lucros', 'Lucros/Prejuízos Acumulados', 'Ajustes de Avaliação Patrimonial', 'Ajustes Acumulados de Conversão', 'Outros Resultados Abrangentes', 'Adiantamento para Futuro Aumento Capital', 'Receita Bruta de Vendas e/ou Serviços', 'Deduções da Receita Bruta', 'Receita Líquida de Vendas e/ou Serviços', 'Custo de Bens e/ou Serviços Vendidos', 'Resultado Bruto', 'Despesas Com Vendas', 'Despesas Gerais e Administrativas', 'Perdas pela Não Recuperabilidade de Ativos\xa0', 'Outras Receitas Operacionais', 'Outras Despesas Operacionais', 'Resultado da Equivalência Patrimonial', 'Financeiras', 'Receitas Financeiras', 'Despesas Financeiras', 'Resultado Não Operacional', 'Receitas', 'Despesas', 'Resultado Antes Tributação/Participações', 'Provisão para IR e Contribuição Social', 'IR Diferido', 'Participações/Contribuições Estatutárias', 'Reversão dos Juros sobre Capital Próprio', 'Part. de Acionistas Não Controladores', 'Lucro/Prejuízo do Período', 'Adj Close']
# Index([                                 20753426.432,
#                                          2408035.072,
#                                          2055229.056,
#                                                    0,
#                                           329968.992,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                22837,
#                                           585470.976,
#                                                    0,
#                                                    0,
#                                               571632,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                13839,
#                                          1317372.032,
#                                               242406,
#                                         16182148.096,
#                                                17994,
#                                         20753426.432,
#                                          1110350.976,
#                                                    0,
#                                                15650,
#                                               123743,
#                                               148240,
#                                                    0,
#                                                    0,
#                                           822718.016,
#                                                    0,
#                                                    0,
#                                                95923,
#                                                    0,
#                                                    0,
#                                                  379,
#                                                    0,
#                                                    0,
#                                                95544,
#                                                    0,
#                                                    0,
#                                                15272,
#                                         19531880.448,
#                                          2540239.104,
#                                         16350974.976,
#                                                24324,
#                                           398897.984,
#                                               217444,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                    0,
#              'Receita Bruta de Vendas e/ou Serviços',
#                          'Deduções da Receita Bruta',
#            'Receita Líquida de Vendas e/ou Serviços',
#               'Custo de Bens e/ou Serviços Vendidos',
#                                    'Resultado Bruto',
#                                'Despesas Com Vendas',
#                  'Despesas Gerais e Administrativas',
#        'Perdas pela Não Recuperabilidade de Ativos ',
#                       'Outras Receitas Operacionais',
#                       'Outras Despesas Operacionais',
#              'Resultado da Equivalência Patrimonial',
#                                        'Financeiras',
#                               'Receitas Financeiras',
#                               'Despesas Financeiras',
#                          'Resultado Não Operacional',
#                                           'Receitas',
#                                           'Despesas',
#           'Resultado Antes Tributação/Participações',
#             'Provisão para IR e Contribuição Social',
#                                        'IR Diferido',
#           'Participações/Contribuições Estatutárias',
#           'Reversão dos Juros sobre Capital Próprio',
#              'Part. de Acionistas Não Controladores',
#                          'Lucro/Prejuízo do Período',
#                                          'Adj Close'],
#       dtype='object')
# BRML3
# Different
# ['Ativo Total', 'Ativo Circulante', 'Caixa e Equivalentes de Caixa', 'Aplicações Financeiras', 'Contas a Receber', 'Estoques', 'Ativos Biológicos', 'Tributos a Recuperar', 'Despesas Antecipadas', 'Outros Ativos Circulantes', 'Ativo Realizável a Longo Prazo', 'Aplicações Financeiras Avaliadas a Valor Justo', 'Aplicações Financeiras Avaliadas ao Custo Amortizado', 'Contas a Receber', 'Estoques', 'Ativos Biológicos', 'Tributos Diferidos', 'Despesas Antecipadas', 'Créditos com Partes Relacionadas', 'Outros Ativos Não Circulantes', 'Investimentos', 'Imobilizado', 'Intangível', 'Diferido', 'Passivo Total', 'Passivo Circulante', 'Obrigações Sociais e Trabalhistas', 'Fornecedores', 'Obrigações Fiscais', 'Empréstimos e Financiamentos', 'Passivos com Partes Relacionadas', 'Dividendos e JCP a Pagar', 'Outros', 'Provisões', 'Passivos sobre Ativos Não-Correntes a Venda e Descontinuados', 'Passivo Não Circulante', 'Empréstimos e Financiamentos', 'Passivos com Partes Relacionadas', 'Outros', 'Tributos Diferidos', 'Adiantamento para Futuro Aumento Capital', 'Provisões', 'Passivos sobre Ativos Não-Correntes a Venda e Descontinuados', 'Lucros e Receitas a Apropriar', 'Participação dos Acionistas Não Controladores', 'Patrimônio Líquido', 'Capital Social Realizado', 'Reservas de Capital', 'Reservas de Reavaliação', 'Reservas de Lucros', 'Lucros/Prejuízos Acumulados', 'Ajustes de Avaliação Patrimonial', 'Ajustes Acumulados de Conversão', 'Outros Resultados Abrangentes', 'Adiantamento para Futuro Aumento Capital', 'Receita Bruta de Vendas e/ou Serviços', 'Deduções da Receita Bruta', 'Receita Líquida de Vendas e/ou Serviços', 'Custo de Bens e/ou Serviços Vendidos', 'Resultado Bruto', 'Despesas Com Vendas', 'Despesas Gerais e Administrativas', 'Perdas pela Não Recuperabilidade de Ativos\xa0', 'Outras Receitas Operacionais', 'Outras Despesas Operacionais', 'Resultado da Equivalência Patrimonial', 'Financeiras', 'Receitas Financeiras', 'Despesas Financeiras', 'Resultado Não Operacional', 'Receitas', 'Despesas', 'Resultado Antes Tributação/Participações', 'Provisão para IR e Contribuição Social', 'IR Diferido', 'Participações/Contribuições Estatutárias', 'Reversão dos Juros sobre Capital Próprio', 'Part. de Acionistas Não Controladores', 'Lucro/Prejuízo do Período', 'Adj Close']
# Index([                                  3287660.032,
#                                          1026049.984,
#                                           911459.968,
#                                                    0,
#                                                61623,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                52967,
#                                                95646,
#                                                    0,
#                                                    0,
#                                                95606,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                   40,
#                                           554764.992,
#                                          1594569.984,
#                                                    0,
#                                                16629,
#                                          3287660.032,
#                                               203910,
#                                                    0,
#                                                 7179,
#                                                57989,
#                                               102943,
#                                                    0,
#                                                    0,
#                                                35314,
#                                                  485,
#                                                    0,
#                                              1269504,
#                                          1214028.032,
#                                                    0,
#                                                46255,
#                                                    0,
#                                                    0,
#                                                 9221,
#                                                    0,
#                                                  398,
#                                                13462,
#                                          1800386.048,
#                                          1846253.056,
#                                                  126,
#                                                    0,
#                                                    0,
#                                               -45993,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                    0,
#              'Receita Bruta de Vendas e/ou Serviços',
#                          'Deduções da Receita Bruta',
#            'Receita Líquida de Vendas e/ou Serviços',
#               'Custo de Bens e/ou Serviços Vendidos',
#                                    'Resultado Bruto',
#                                'Despesas Com Vendas',
#                  'Despesas Gerais e Administrativas',
#        'Perdas pela Não Recuperabilidade de Ativos ',
#                       'Outras Receitas Operacionais',
#                       'Outras Despesas Operacionais',
#              'Resultado da Equivalência Patrimonial',
#                                        'Financeiras',
#                               'Receitas Financeiras',
#                               'Despesas Financeiras',
#                          'Resultado Não Operacional',
#                                           'Receitas',
#                                           'Despesas',
#           'Resultado Antes Tributação/Participações',
#             'Provisão para IR e Contribuição Social',
#                                        'IR Diferido',
#           'Participações/Contribuições Estatutárias',
#           'Reversão dos Juros sobre Capital Próprio',
#              'Part. de Acionistas Não Controladores',
#                          'Lucro/Prejuízo do Período',
#                                          'Adj Close'],
#       dtype='object')
# BBDC4
# Different
# ['Ativo Total', 'Ativo Circulante', 'Caixa e Equivalentes de Caixa', 'Aplicações Financeiras', 'Contas a Receber', 'Estoques', 'Ativos Biológicos', 'Tributos a Recuperar', 'Despesas Antecipadas', 'Outros Ativos Circulantes', 'Ativo Realizável a Longo Prazo', 'Aplicações Financeiras Avaliadas a Valor Justo', 'Aplicações Financeiras Avaliadas ao Custo Amortizado', 'Contas a Receber', 'Estoques', 'Ativos Biológicos', 'Tributos Diferidos', 'Despesas Antecipadas', 'Créditos com Partes Relacionadas', 'Outros Ativos Não Circulantes', 'Investimentos', 'Imobilizado', 'Intangível', 'Diferido', 'Passivo Total', 'Passivo Circulante', 'Obrigações Sociais e Trabalhistas', 'Fornecedores', 'Obrigações Fiscais', 'Empréstimos e Financiamentos', 'Passivos com Partes Relacionadas', 'Dividendos e JCP a Pagar', 'Outros', 'Provisões', 'Passivos sobre Ativos Não-Correntes a Venda e Descontinuados', 'Passivo Não Circulante', 'Empréstimos e Financiamentos', 'Passivos com Partes Relacionadas', 'Outros', 'Tributos Diferidos', 'Adiantamento para Futuro Aumento Capital', 'Provisões', 'Passivos sobre Ativos Não-Correntes a Venda e Descontinuados', 'Lucros e Receitas a Apropriar', 'Participação dos Acionistas Não Controladores', 'Patrimônio Líquido', 'Capital Social Realizado', 'Reservas de Capital', 'Reservas de Reavaliação', 'Reservas de Lucros', 'Lucros/Prejuízos Acumulados', 'Ajustes de Avaliação Patrimonial', 'Ajustes Acumulados de Conversão', 'Outros Resultados Abrangentes', 'Adiantamento para Futuro Aumento Capital', 'Receita Bruta de Vendas e/ou Serviços', 'Deduções da Receita Bruta', 'Receita Líquida de Vendas e/ou Serviços', 'Custo de Bens e/ou Serviços Vendidos', 'Resultado Bruto', 'Despesas Com Vendas', 'Despesas Gerais e Administrativas', 'Perdas pela Não Recuperabilidade de Ativos\xa0', 'Outras Receitas Operacionais', 'Outras Despesas Operacionais', 'Resultado da Equivalência Patrimonial', 'Financeiras', 'Receitas Financeiras', 'Despesas Financeiras', 'Resultado Não Operacional', 'Receitas', 'Despesas', 'Resultado Antes Tributação/Participações', 'Provisão para IR e Contribuição Social', 'IR Diferido', 'Participações/Contribuições Estatutárias', 'Reversão dos Juros sobre Capital Próprio', 'Part. de Acionistas Não Controladores', 'Lucro/Prejuízo do Período', 'Adj Close']
# Index([                              422705725.44,
#                                      319213731.84,
#                                       7259572.224,
#                                      56603541.504,
#                                     114072592.384,
#                                      26528739.328,
#                                             95551,
#                                      74329923.584,
#                                       6263071.232,
#                                      32153868.288,
#                                       1906859.008,
#                                       98571550.72,
#                                        747148.032,
#                                      18299867.136,
#                                            457016,
#                                                 0,
#                                       51344199.68,
#                                      12412131.328,
#                                      13726867.456,
#                                       1584327.936,
#                                       4920444.928,
#                                        822907.008,
#                                       2506700.032,
#                                             10021,
#                                                 0,
#                                       1580817.024,
#                                      422705725.44,
#                                     240695738.368,
#                                      85464170.496,
#                                      55530774.528,
#                                       1818066.944,
#                                        231152.992,
#                                        2307374.08,
#                                      13309754.368,
#                                       6446913.024,
#                                       1426605.056,
#                                      74160922.624,
#                                     146988056.576,
#                                      53705547.776,
#                                      31933005.824,
#                                       4733190.144,
#                                                 0,
#                                                 0,
#                                        693777.024,
#                                      10102688.768,
#                                                 0,
#                                      45819846.656,
#                                            227078,
#                                        627014.016,
#                                      34167824.384,
#                                      23000000.512,
#                                             62614,
#                                                 0,
#                                      10971236.352,
#                                            133976,
#                                                 0,
#            'Receitas da Intermediação Financeira',
#            'Despesas da Intermediação Financeira',
#        'Resultado Bruto Intermediação Financeira',
#           'Outras Despesas/Receitas Operacionais',
#               'Receitas de Prestação de Serviços',
#                             'Despesas de Pessoal',
#                 'Outras Despesas Administrativas',
#                            'Despesas Tributárias',
#                    'Outras Receitas Operacionais',
#                    'Outras Despesas Operacionais',
#           'Resultado da Equivalência Patrimonial',
#                           'Resultado Operacional',
#                       'Resultado Não Operacional',
#                                        'Receitas',
#                                        'Despesas',
#        'Resultado Antes Tributação/Participações',
#          'Provisão para IR e Contribuição Social',
#                                     'IR Diferido',
#        'Participações/Contribuições Estatutárias',
#        'Reversão dos Juros sobre Capital Próprio',
#           'Part. de Acionistas Não Controladores',
#                       'Lucro/Prejuízo do Período',
#                                       'Adj Close'],
#       dtype='object')
# BRAP4
# Different
# ['Ativo Total', 'Ativo Circulante', 'Caixa e Equivalentes de Caixa', 'Aplicações Financeiras', 'Contas a Receber', 'Estoques', 'Ativos Biológicos', 'Tributos a Recuperar', 'Despesas Antecipadas', 'Outros Ativos Circulantes', 'Ativo Realizável a Longo Prazo', 'Aplicações Financeiras Avaliadas a Valor Justo', 'Aplicações Financeiras Avaliadas ao Custo Amortizado', 'Contas a Receber', 'Estoques', 'Ativos Biológicos', 'Tributos Diferidos', 'Despesas Antecipadas', 'Créditos com Partes Relacionadas', 'Outros Ativos Não Circulantes', 'Investimentos', 'Imobilizado', 'Intangível', 'Diferido', 'Passivo Total', 'Passivo Circulante', 'Obrigações Sociais e Trabalhistas', 'Fornecedores', 'Obrigações Fiscais', 'Empréstimos e Financiamentos', 'Passivos com Partes Relacionadas', 'Dividendos e JCP a Pagar', 'Outros', 'Provisões', 'Passivos sobre Ativos Não-Correntes a Venda e Descontinuados', 'Passivo Não Circulante', 'Empréstimos e Financiamentos', 'Passivos com Partes Relacionadas', 'Outros', 'Tributos Diferidos', 'Adiantamento para Futuro Aumento Capital', 'Provisões', 'Passivos sobre Ativos Não-Correntes a Venda e Descontinuados', 'Lucros e Receitas a Apropriar', 'Participação dos Acionistas Não Controladores', 'Patrimônio Líquido', 'Capital Social Realizado', 'Reservas de Capital', 'Reservas de Reavaliação', 'Reservas de Lucros', 'Lucros/Prejuízos Acumulados', 'Ajustes de Avaliação Patrimonial', 'Ajustes Acumulados de Conversão', 'Outros Resultados Abrangentes', 'Adiantamento para Futuro Aumento Capital', 'Receita Bruta de Vendas e/ou Serviços', 'Deduções da Receita Bruta', 'Receita Líquida de Vendas e/ou Serviços', 'Custo de Bens e/ou Serviços Vendidos', 'Resultado Bruto', 'Despesas Com Vendas', 'Despesas Gerais e Administrativas', 'Perdas pela Não Recuperabilidade de Ativos\xa0', 'Outras Receitas Operacionais', 'Outras Despesas Operacionais', 'Resultado da Equivalência Patrimonial', 'Financeiras', 'Receitas Financeiras', 'Despesas Financeiras', 'Resultado Não Operacional', 'Receitas', 'Despesas', 'Resultado Antes Tributação/Participações', 'Provisão para IR e Contribuição Social', 'IR Diferido', 'Participações/Contribuições Estatutárias', 'Reversão dos Juros sobre Capital Próprio', 'Part. de Acionistas Não Controladores', 'Lucro/Prejuízo do Período', 'Adj Close']
# Index([                                  6524766.208,
#                                           435220.992,
#                                           389860.992,
#                                                    0,
#                                                45360,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                79080,
#                                                    0,
#                                                    0,
#                                                79080,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                    0,
#                                          6010352.128,
#                                                  111,
#                                                    0,
#                                                    2,
#                                          6524766.208,
#                                          1466269.056,
#                                                    0,
#                                                    0,
#                                                   50,
#                                                    0,
#                                                    0,
#                                                    0,
#                                          1466219.008,
#                                                    0,
#                                                    0,
#                                                81638,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                81638,
#                                                    0,
#                                                    0,
#                                                    0,
#                                          4976859.136,
#                                              3000000,
#                                                    0,
#                                                    0,
#                                           856241.024,
#                                          1120617.984,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                    0,
#              'Receita Bruta de Vendas e/ou Serviços',
#                          'Deduções da Receita Bruta',
#            'Receita Líquida de Vendas e/ou Serviços',
#               'Custo de Bens e/ou Serviços Vendidos',
#                                    'Resultado Bruto',
#                                'Despesas Com Vendas',
#                  'Despesas Gerais e Administrativas',
#        'Perdas pela Não Recuperabilidade de Ativos ',
#                       'Outras Receitas Operacionais',
#                       'Outras Despesas Operacionais',
#              'Resultado da Equivalência Patrimonial',
#                                        'Financeiras',
#                               'Receitas Financeiras',
#                               'Despesas Financeiras',
#                          'Resultado Não Operacional',
#                                           'Receitas',
#                                           'Despesas',
#           'Resultado Antes Tributação/Participações',
#             'Provisão para IR e Contribuição Social',
#                                        'IR Diferido',
#           'Participações/Contribuições Estatutárias',
#           'Reversão dos Juros sobre Capital Próprio',
#              'Part. de Acionistas Não Controladores',
#                          'Lucro/Prejuízo do Período',
#                                          'Adj Close'],
#       dtype='object')
# BBAS3
# Different
# ['Ativo Total', 'Ativo Circulante', 'Caixa e Equivalentes de Caixa', 'Aplicações Financeiras', 'Contas a Receber', 'Estoques', 'Ativos Biológicos', 'Tributos a Recuperar', 'Despesas Antecipadas', 'Outros Ativos Circulantes', 'Ativo Realizável a Longo Prazo', 'Aplicações Financeiras Avaliadas a Valor Justo', 'Aplicações Financeiras Avaliadas ao Custo Amortizado', 'Contas a Receber', 'Estoques', 'Ativos Biológicos', 'Tributos Diferidos', 'Despesas Antecipadas', 'Créditos com Partes Relacionadas', 'Outros Ativos Não Circulantes', 'Investimentos', 'Imobilizado', 'Intangível', 'Diferido', 'Passivo Total', 'Passivo Circulante', 'Obrigações Sociais e Trabalhistas', 'Fornecedores', 'Obrigações Fiscais', 'Empréstimos e Financiamentos', 'Passivos com Partes Relacionadas', 'Dividendos e JCP a Pagar', 'Outros', 'Provisões', 'Passivos sobre Ativos Não-Correntes a Venda e Descontinuados', 'Passivo Não Circulante', 'Empréstimos e Financiamentos', 'Passivos com Partes Relacionadas', 'Outros', 'Tributos Diferidos', 'Adiantamento para Futuro Aumento Capital', 'Provisões', 'Passivos sobre Ativos Não-Correntes a Venda e Descontinuados', 'Lucros e Receitas a Apropriar', 'Participação dos Acionistas Não Controladores', 'Patrimônio Líquido', 'Capital Social Realizado', 'Reservas de Capital', 'Reservas de Reavaliação', 'Reservas de Lucros', 'Lucros/Prejuízos Acumulados', 'Ajustes de Avaliação Patrimonial', 'Ajustes Acumulados de Conversão', 'Outros Resultados Abrangentes', 'Adiantamento para Futuro Aumento Capital', 'Receita Bruta de Vendas e/ou Serviços', 'Deduções da Receita Bruta', 'Receita Líquida de Vendas e/ou Serviços', 'Custo de Bens e/ou Serviços Vendidos', 'Resultado Bruto', 'Despesas Com Vendas', 'Despesas Gerais e Administrativas', 'Perdas pela Não Recuperabilidade de Ativos\xa0', 'Outras Receitas Operacionais', 'Outras Despesas Operacionais', 'Resultado da Equivalência Patrimonial', 'Financeiras', 'Receitas Financeiras', 'Despesas Financeiras', 'Resultado Não Operacional', 'Receitas', 'Despesas', 'Resultado Antes Tributação/Participações', 'Provisão para IR e Contribuição Social', 'IR Diferido', 'Participações/Contribuições Estatutárias', 'Reversão dos Juros sobre Capital Próprio', 'Part. de Acionistas Não Controladores', 'Lucro/Prejuízo do Período', 'Adj Close']
# Index([                             458873110.528,
#                                     255076958.208,
#                                       6846648.832,
#                                      54096490.496,
#                                        45920051.2,
#                                      38238285.824,
#                                            137788,
#                                      74623328.256,
#                                             -3126,
#                                       34117867.52,
#                                       1099636.992,
#                                      195578757.12,
#                                       16995189.76,
#                                      40033468.416,
#                                                 0,
#                                                 0,
#                                     100975788.032,
#                                             16624,
#                                      34257012.736,
#                                       3300670.976,
#                                         8217395.2,
#                                       1589484.032,
#                                       3037093.888,
#                                       2939099.904,
#                                                 0,
#                                        651716.992,
#                                     458873110.528,
#                                     340910768.128,
#                                     191053103.104,
#                                          76199936,
#                                        745494.016,
#                                       2437594.112,
#                                       1314606.976,
#                                       3398479.872,
#                                      12015663.104,
#                                                95,
#                                      53745790.976,
#                                      89908027.392,
#                                      38756876.288,
#                                       9139306.496,
#                                       1918569.984,
#                                                 0,
#                                                 0,
#                                       1609876.992,
#                                       7624203.776,
#                                               382,
#                                      30858809.344,
#                                        165488.992,
#                                                 0,
#                                      27888850.944,
#                                      13699011.584,
#                                              5189,
#                                              7370,
#                                      12749555.712,
#                                            -33366,
#                                       1461089.024,
#            'Receitas da Intermediação Financeira',
#            'Despesas da Intermediação Financeira',
#        'Resultado Bruto Intermediação Financeira',
#           'Outras Despesas/Receitas Operacionais',
#               'Receitas de Prestação de Serviços',
#                             'Despesas de Pessoal',
#                 'Outras Despesas Administrativas',
#                            'Despesas Tributárias',
#                    'Outras Receitas Operacionais',
#                    'Outras Despesas Operacionais',
#           'Resultado da Equivalência Patrimonial',
#                           'Resultado Operacional',
#                       'Resultado Não Operacional',
#                                        'Receitas',
#                                        'Despesas',
#        'Resultado Antes Tributação/Participações',
#          'Provisão para IR e Contribuição Social',
#                                     'IR Diferido',
#        'Participações/Contribuições Estatutárias',
#        'Reversão dos Juros sobre Capital Próprio',
#           'Part. de Acionistas Não Controladores',
#                       'Lucro/Prejuízo do Período',
#                                       'Adj Close'],
#       dtype='object')
# BRKM5
# Different
# ['Ativo Total', 'Ativo Circulante', 'Caixa e Equivalentes de Caixa', 'Aplicações Financeiras', 'Contas a Receber', 'Estoques', 'Ativos Biológicos', 'Tributos a Recuperar', 'Despesas Antecipadas', 'Outros Ativos Circulantes', 'Ativo Realizável a Longo Prazo', 'Aplicações Financeiras Avaliadas a Valor Justo', 'Aplicações Financeiras Avaliadas ao Custo Amortizado', 'Contas a Receber', 'Estoques', 'Ativos Biológicos', 'Tributos Diferidos', 'Despesas Antecipadas', 'Créditos com Partes Relacionadas', 'Outros Ativos Não Circulantes', 'Investimentos', 'Imobilizado', 'Intangível', 'Diferido', 'Passivo Total', 'Passivo Circulante', 'Obrigações Sociais e Trabalhistas', 'Fornecedores', 'Obrigações Fiscais', 'Empréstimos e Financiamentos', 'Passivos com Partes Relacionadas', 'Dividendos e JCP a Pagar', 'Outros', 'Provisões', 'Passivos sobre Ativos Não-Correntes a Venda e Descontinuados', 'Passivo Não Circulante', 'Empréstimos e Financiamentos', 'Passivos com Partes Relacionadas', 'Outros', 'Tributos Diferidos', 'Adiantamento para Futuro Aumento Capital', 'Provisões', 'Passivos sobre Ativos Não-Correntes a Venda e Descontinuados', 'Lucros e Receitas a Apropriar', 'Participação dos Acionistas Não Controladores', 'Patrimônio Líquido', 'Capital Social Realizado', 'Reservas de Capital', 'Reservas de Reavaliação', 'Reservas de Lucros', 'Lucros/Prejuízos Acumulados', 'Ajustes de Avaliação Patrimonial', 'Ajustes Acumulados de Conversão', 'Outros Resultados Abrangentes', 'Adiantamento para Futuro Aumento Capital', 'Receita Bruta de Vendas e/ou Serviços', 'Deduções da Receita Bruta', 'Receita Líquida de Vendas e/ou Serviços', 'Custo de Bens e/ou Serviços Vendidos', 'Resultado Bruto', 'Despesas Com Vendas', 'Despesas Gerais e Administrativas', 'Perdas pela Não Recuperabilidade de Ativos\xa0', 'Outras Receitas Operacionais', 'Outras Despesas Operacionais', 'Resultado da Equivalência Patrimonial', 'Financeiras', 'Receitas Financeiras', 'Despesas Financeiras', 'Resultado Não Operacional', 'Receitas', 'Despesas', 'Resultado Antes Tributação/Participações', 'Provisão para IR e Contribuição Social', 'IR Diferido', 'Participações/Contribuições Estatutárias', 'Reversão dos Juros sobre Capital Próprio', 'Part. de Acionistas Não Controladores', 'Lucro/Prejuízo do Período', 'Adj Close']
# Index([                                 22327648.256,
#                                           7363473.92,
#                                          1842835.968,
#                                                    0,
#                                          2600701.952,
#                                          2782283.008,
#                                                    0,
#                                                    0,
#                                                    0,
#                                           137652.992,
#                                          2120749.056,
#                                                    0,
#                                                    0,
#                                          2006029.056,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                54448,
#                                                60272,
#                                                39631,
#                                           10158873.6,
#                                           246800.992,
#                                          2398119.936,
#                                         22327648.256,
#                                          5979637.248,
#                                                    0,
#                                          4178364.928,
#                                               145888,
#                                          1257102.984,
#                                                    0,
#                                                 7131,
#                                           391150.016,
#                                                    0,
#                                                    0,
#                                         10326930.432,
#                                          8926815.232,
#                                                    0,
#                                          1400114.944,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                21750,
#                                                    0,
#                                           5999331.84,
#                                          5375801.856,
#                                           457460.992,
#                                                    0,
#                                           550326.016,
#                                          -384256.992,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                    0,
#              'Receita Bruta de Vendas e/ou Serviços',
#                          'Deduções da Receita Bruta',
#            'Receita Líquida de Vendas e/ou Serviços',
#               'Custo de Bens e/ou Serviços Vendidos',
#                                    'Resultado Bruto',
#                                'Despesas Com Vendas',
#                  'Despesas Gerais e Administrativas',
#        'Perdas pela Não Recuperabilidade de Ativos ',
#                       'Outras Receitas Operacionais',
#                       'Outras Despesas Operacionais',
#              'Resultado da Equivalência Patrimonial',
#                                        'Financeiras',
#                               'Receitas Financeiras',
#                               'Despesas Financeiras',
#                          'Resultado Não Operacional',
#                                           'Receitas',
#                                           'Despesas',
#           'Resultado Antes Tributação/Participações',
#             'Provisão para IR e Contribuição Social',
#                                        'IR Diferido',
#           'Participações/Contribuições Estatutárias',
#           'Reversão dos Juros sobre Capital Próprio',
#              'Part. de Acionistas Não Controladores',
#                          'Lucro/Prejuízo do Período',
#                                          'Adj Close'],
#       dtype='object')
# BRFS3
# Different
# ['Ativo Total', 'Ativo Circulante', 'Caixa e Equivalentes de Caixa', 'Aplicações Financeiras', 'Contas a Receber', 'Estoques', 'Ativos Biológicos', 'Tributos a Recuperar', 'Despesas Antecipadas', 'Outros Ativos Circulantes', 'Ativo Realizável a Longo Prazo', 'Aplicações Financeiras Avaliadas a Valor Justo', 'Aplicações Financeiras Avaliadas ao Custo Amortizado', 'Contas a Receber', 'Estoques', 'Ativos Biológicos', 'Tributos Diferidos', 'Despesas Antecipadas', 'Créditos com Partes Relacionadas', 'Outros Ativos Não Circulantes', 'Investimentos', 'Imobilizado', 'Intangível', 'Diferido', 'Passivo Total', 'Passivo Circulante', 'Obrigações Sociais e Trabalhistas', 'Fornecedores', 'Obrigações Fiscais', 'Empréstimos e Financiamentos', 'Passivos com Partes Relacionadas', 'Dividendos e JCP a Pagar', 'Outros', 'Provisões', 'Passivos sobre Ativos Não-Correntes a Venda e Descontinuados', 'Passivo Não Circulante', 'Empréstimos e Financiamentos', 'Passivos com Partes Relacionadas', 'Outros', 'Tributos Diferidos', 'Adiantamento para Futuro Aumento Capital', 'Provisões', 'Passivos sobre Ativos Não-Correntes a Venda e Descontinuados', 'Lucros e Receitas a Apropriar', 'Participação dos Acionistas Não Controladores', 'Patrimônio Líquido', 'Capital Social Realizado', 'Reservas de Capital', 'Reservas de Reavaliação', 'Reservas de Lucros', 'Lucros/Prejuízos Acumulados', 'Ajustes de Avaliação Patrimonial', 'Ajustes Acumulados de Conversão', 'Outros Resultados Abrangentes', 'Adiantamento para Futuro Aumento Capital', 'Receita Bruta de Vendas e/ou Serviços', 'Deduções da Receita Bruta', 'Receita Líquida de Vendas e/ou Serviços', 'Custo de Bens e/ou Serviços Vendidos', 'Resultado Bruto', 'Despesas Com Vendas', 'Despesas Gerais e Administrativas', 'Perdas pela Não Recuperabilidade de Ativos\xa0', 'Outras Receitas Operacionais', 'Outras Despesas Operacionais', 'Resultado da Equivalência Patrimonial', 'Financeiras', 'Receitas Financeiras', 'Despesas Financeiras', 'Resultado Não Operacional', 'Receitas', 'Despesas', 'Resultado Antes Tributação/Participações', 'Provisão para IR e Contribuição Social', 'IR Diferido', 'Participações/Contribuições Estatutárias', 'Reversão dos Juros sobre Capital Próprio', 'Part. de Acionistas Não Controladores', 'Lucro/Prejuízo do Período', 'Adj Close']
# Index([                                   9033825.28,
#                                          4865534.976,
#                                              1004456,
#                                                    0,
#                                           1385256.96,
#                                           1625912.96,
#                                                    0,
#                                                    0,
#                                                    0,
#                                           849908.992,
#                                           960532.992,
#                                                    0,
#                                                    0,
#                                                12295,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                    0,
#                                           948238.016,
#                                               174106,
#                                          2875883.008,
#                                                    0,
#                                               157768,
#                                           9033825.28,
#                                          2648944.128,
#                                                    0,
#                                          1007651.968,
#                                                69454,
#                                           1285783.04,
#                                                    0,
#                                                   32,
#                                               131094,
#                                           154928.992,
#                                                    0,
#                                           3145870.08,
#                                          2765786.112,
#                                                    0,
#                                               150210,
#                                                    0,
#                                                    0,
#                                               229874,
#                                                    0,
#                                                   72,
#                                                  512,
#                                           3238426.88,
#                                          3445042.944,
#                                                    0,
#                                                    0,
#                                           706289.984,
#                                          -912905.984,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                    0,
#              'Receita Bruta de Vendas e/ou Serviços',
#                          'Deduções da Receita Bruta',
#            'Receita Líquida de Vendas e/ou Serviços',
#               'Custo de Bens e/ou Serviços Vendidos',
#                                    'Resultado Bruto',
#                                'Despesas Com Vendas',
#                  'Despesas Gerais e Administrativas',
#        'Perdas pela Não Recuperabilidade de Ativos ',
#                       'Outras Receitas Operacionais',
#                       'Outras Despesas Operacionais',
#              'Resultado da Equivalência Patrimonial',
#                                        'Financeiras',
#                               'Receitas Financeiras',
#                               'Despesas Financeiras',
#                          'Resultado Não Operacional',
#                                           'Receitas',
#                                           'Despesas',
#           'Resultado Antes Tributação/Participações',
#             'Provisão para IR e Contribuição Social',
#                                        'IR Diferido',
#           'Participações/Contribuições Estatutárias',
#           'Reversão dos Juros sobre Capital Próprio',
#              'Part. de Acionistas Não Controladores',
#                          'Lucro/Prejuízo do Período',
#                                          'Adj Close'],
#       dtype='object')
# BPAC11
# Different
# ...
#                                          2646164.992,
#                                          2602178.048,
#                                          1670674.944,
#                                                    0,
#                                         55928918.016,
#                                         36670758.912,
#                                                   63,
#                                         12811420.672,
#                                                    0,
#                                                    0,
#                                          6446678.016,
#                                                    0,
#                                                93628,
#                                          5521273.856,
#                                         95551520.768,
#                                         47434190.848,
#                                          -160771.008,
#                                                    0,
#                                         25954996.224,
#                                         19259267.072,
#                                                    0,
#                                                    0,
#                                                    0,
#                                          3063833.088,
#              'Receita Bruta de Vendas e/ou Serviços',
#                          'Deduções da Receita Bruta',
#            'Receita Líquida de Vendas e/ou Serviços',
#               'Custo de Bens e/ou Serviços Vendidos',
#                                    'Resultado Bruto',
#                                'Despesas Com Vendas',
#                  'Despesas Gerais e Administrativas',
#        'Perdas pela Não Recuperabilidade de Ativos ',
#                       'Outras Receitas Operacionais',
#                       'Outras Despesas Operacionais',
#              'Resultado da Equivalência Patrimonial',
#                                        'Financeiras',
#                               'Receitas Financeiras',
#                               'Despesas Financeiras',
#                          'Resultado Não Operacional',
#                                           'Receitas',
#                                           'Despesas',
#           'Resultado Antes Tributação/Participações',
#             'Provisão para IR e Contribuição Social',
#                                        'IR Diferido',
#           'Participações/Contribuições Estatutárias',
#           'Reversão dos Juros sobre Capital Próprio',
#              'Part. de Acionistas Não Controladores',
#                          'Lucro/Prejuízo do Período',
#                                          'Adj Close'],
#       dtype='object')
# WEGE3
# Different
# ['Ativo Total', 'Ativo Circulante', 'Caixa e Equivalentes de Caixa', 'Aplicações Financeiras', 'Contas a Receber', 'Estoques', 'Ativos Biológicos', 'Tributos a Recuperar', 'Despesas Antecipadas', 'Outros Ativos Circulantes', 'Ativo Realizável a Longo Prazo', 'Aplicações Financeiras Avaliadas a Valor Justo', 'Aplicações Financeiras Avaliadas ao Custo Amortizado', 'Contas a Receber', 'Estoques', 'Ativos Biológicos', 'Tributos Diferidos', 'Despesas Antecipadas', 'Créditos com Partes Relacionadas', 'Outros Ativos Não Circulantes', 'Investimentos', 'Imobilizado', 'Intangível', 'Diferido', 'Passivo Total', 'Passivo Circulante', 'Obrigações Sociais e Trabalhistas', 'Fornecedores', 'Obrigações Fiscais', 'Empréstimos e Financiamentos', 'Passivos com Partes Relacionadas', 'Dividendos e JCP a Pagar', 'Outros', 'Provisões', 'Passivos sobre Ativos Não-Correntes a Venda e Descontinuados', 'Passivo Não Circulante', 'Empréstimos e Financiamentos', 'Passivos com Partes Relacionadas', 'Outros', 'Tributos Diferidos', 'Adiantamento para Futuro Aumento Capital', 'Provisões', 'Passivos sobre Ativos Não-Correntes a Venda e Descontinuados', 'Lucros e Receitas a Apropriar', 'Participação dos Acionistas Não Controladores', 'Patrimônio Líquido', 'Capital Social Realizado', 'Reservas de Capital', 'Reservas de Reavaliação', 'Reservas de Lucros', 'Lucros/Prejuízos Acumulados', 'Ajustes de Avaliação Patrimonial', 'Ajustes Acumulados de Conversão', 'Outros Resultados Abrangentes', 'Adiantamento para Futuro Aumento Capital', 'Receita Bruta de Vendas e/ou Serviços', 'Deduções da Receita Bruta', 'Receita Líquida de Vendas e/ou Serviços', 'Custo de Bens e/ou Serviços Vendidos', 'Resultado Bruto', 'Despesas Com Vendas', 'Despesas Gerais e Administrativas', 'Perdas pela Não Recuperabilidade de Ativos\xa0', 'Outras Receitas Operacionais', 'Outras Despesas Operacionais', 'Resultado da Equivalência Patrimonial', 'Financeiras', 'Receitas Financeiras', 'Despesas Financeiras', 'Resultado Não Operacional', 'Receitas', 'Despesas', 'Resultado Antes Tributação/Participações', 'Provisão para IR e Contribuição Social', 'IR Diferido', 'Participações/Contribuições Estatutárias', 'Reversão dos Juros sobre Capital Próprio', 'Part. de Acionistas Não Controladores', 'Lucro/Prejuízo do Período', 'Adj Close']
# Index([                                  5298454.016,
#                                          4037732.096,
#                                          1820203.008,
#                                                    0,
#                                          1024857.024,
#                                           981142.976,
#                                                    0,
#                                                    0,
#                                                    0,
#                                           211528.992,
#                                           166863.008,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                    0,
#                                           166863.008,
#                                                48002,
#                                           963769.984,
#                                                    0,
#                                                82087,
#                                          5298454.016,
#                                          2324331.008,
#                                                    0,
#                                               324716,
#                                               188090,
#                                          1238441.984,
#                                                    0,
#                                                25890,
#                                           547193.024,
#                                                    0,
#                                                    0,
#                                           810860.032,
#                                               644736,
#                                                    0,
#                                               166124,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                40980,
#                                          2122283.008,
#                                          1360499.968,
#                                                    0,
#                                                 6234,
#                                               461920,
#                                           293628.992,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                    0,
#              'Receita Bruta de Vendas e/ou Serviços',
#                          'Deduções da Receita Bruta',
#            'Receita Líquida de Vendas e/ou Serviços',
#               'Custo de Bens e/ou Serviços Vendidos',
#                                    'Resultado Bruto',
#                                'Despesas Com Vendas',
#                  'Despesas Gerais e Administrativas',
#        'Perdas pela Não Recuperabilidade de Ativos ',
#                       'Outras Receitas Operacionais',
#                       'Outras Despesas Operacionais',
#              'Resultado da Equivalência Patrimonial',
#                                        'Financeiras',
#                               'Receitas Financeiras',
#                               'Despesas Financeiras',
#                          'Resultado Não Operacional',
#                                           'Receitas',
#                                           'Despesas',
#           'Resultado Antes Tributação/Participações',
#             'Provisão para IR e Contribuição Social',
#                                        'IR Diferido',
#           'Participações/Contribuições Estatutárias',
#           'Reversão dos Juros sobre Capital Próprio',
#              'Part. de Acionistas Não Controladores',
#                          'Lucro/Prejuízo do Período',
#                                          'Adj Close'],
#       dtype='object')
# YDUQ3
# Different
# ['Ativo Total', 'Ativo Circulante', 'Caixa e Equivalentes de Caixa', 'Aplicações Financeiras', 'Contas a Receber', 'Estoques', 'Ativos Biológicos', 'Tributos a Recuperar', 'Despesas Antecipadas', 'Outros Ativos Circulantes', 'Ativo Realizável a Longo Prazo', 'Aplicações Financeiras Avaliadas a Valor Justo', 'Aplicações Financeiras Avaliadas ao Custo Amortizado', 'Contas a Receber', 'Estoques', 'Ativos Biológicos', 'Tributos Diferidos', 'Despesas Antecipadas', 'Créditos com Partes Relacionadas', 'Outros Ativos Não Circulantes', 'Investimentos', 'Imobilizado', 'Intangível', 'Diferido', 'Passivo Total', 'Passivo Circulante', 'Obrigações Sociais e Trabalhistas', 'Fornecedores', 'Obrigações Fiscais', 'Empréstimos e Financiamentos', 'Passivos com Partes Relacionadas', 'Dividendos e JCP a Pagar', 'Outros', 'Provisões', 'Passivos sobre Ativos Não-Correntes a Venda e Descontinuados', 'Passivo Não Circulante', 'Empréstimos e Financiamentos', 'Passivos com Partes Relacionadas', 'Outros', 'Tributos Diferidos', 'Adiantamento para Futuro Aumento Capital', 'Provisões', 'Passivos sobre Ativos Não-Correntes a Venda e Descontinuados', 'Lucros e Receitas a Apropriar', 'Participação dos Acionistas Não Controladores', 'Patrimônio Líquido', 'Capital Social Realizado', 'Reservas de Capital', 'Reservas de Reavaliação', 'Reservas de Lucros', 'Lucros/Prejuízos Acumulados', 'Ajustes de Avaliação Patrimonial', 'Ajustes Acumulados de Conversão', 'Outros Resultados Abrangentes', 'Adiantamento para Futuro Aumento Capital', 'Receita Bruta de Vendas e/ou Serviços', 'Deduções da Receita Bruta', 'Receita Líquida de Vendas e/ou Serviços', 'Custo de Bens e/ou Serviços Vendidos', 'Resultado Bruto', 'Despesas Com Vendas', 'Despesas Gerais e Administrativas', 'Perdas pela Não Recuperabilidade de Ativos\xa0', 'Outras Receitas Operacionais', 'Outras Despesas Operacionais', 'Resultado da Equivalência Patrimonial', 'Financeiras', 'Receitas Financeiras', 'Despesas Financeiras', 'Resultado Não Operacional', 'Receitas', 'Despesas', 'Resultado Antes Tributação/Participações', 'Provisão para IR e Contribuição Social', 'IR Diferido', 'Participações/Contribuições Estatutárias', 'Reversão dos Juros sobre Capital Próprio', 'Part. de Acionistas Não Controladores', 'Lucro/Prejuízo do Período', 'Adj Close']
# Index([                                   676081.024,
#                                           409313.984,
#                                               271436,
#                                                    0,
#                                               120707,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                17171,
#                                                 3219,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                 3219,
#                                                69753,
#                                           182451.008,
#                                                    0,
#                                                11344,
#                                           676081.024,
#                                           170527.008,
#                                                    0,
#                                                20954,
#                                                14913,
#                                                  804,
#                                                    0,
#                                                    0,
#                                               133856,
#                                                    0,
#                                                    0,
#                                                19835,
#                                                    0,
#                                                    0,
#                                                 2655,
#                                                    0,
#                                                    0,
#                                                17180,
#                                                    0,
#                                                27181,
#                                                    0,
#                                           458537.984,
#                                           295236.992,
#                                                96482,
#                                                    0,
#                                                13657,
#                                                53162,
#                                                    0,
#                                                    0,
#                                                    0,
#                                                    0,
#              'Receita Bruta de Vendas e/ou Serviços',
#                          'Deduções da Receita Bruta',
#            'Receita Líquida de Vendas e/ou Serviços',
#               'Custo de Bens e/ou Serviços Vendidos',
#                                    'Resultado Bruto',
#                                'Despesas Com Vendas',
#                  'Despesas Gerais e Administrativas',
#        'Perdas pela Não Recuperabilidade de Ativos ',
#                       'Outras Receitas Operacionais',
#                       'Outras Despesas Operacionais',
#              'Resultado da Equivalência Patrimonial',
#                                        'Financeiras',
#                               'Receitas Financeiras',
#                               'Despesas Financeiras',
#                          'Resultado Não Operacional',
#                                           'Receitas',
#                                           'Despesas',
#           'Resultado Antes Tributação/Participações',
#             'Provisão para IR e Contribuição Social',
#                                        'IR Diferido',
#           'Participações/Contribuições Estatutárias',
#           'Reversão dos Juros sobre Capital Próprio',
#              'Part. de Acionistas Não Controladores',
#                          'Lucro/Prejuízo do Período',
#                                          'Adj Close'],
#       dtype='object')

# %% [markdown]
# Selecting the end date (date of the last balance of companies) and creating the start date (getting last 5 years of data)
